# %%
from google.colab import drive
drive.mount('/content/drive',force_remount= True)

# %%
ls
# Out:
# drive/  sample_data/

# %% [markdown]
# ### Import libs

# %%
from __future__ import division
from __future__ import print_function
from __future__ import absolute_import
import random
import pprint
import sys
import time
import numpy as np
from optparse import OptionParser
import pickle
import math
import cv2
import copy
from matplotlib import pyplot as plt
import tensorflow as tf
import pandas as pd
import os

from sklearn.metrics import average_precision_score
from skimage import io

from keras import backend as K
from keras.optimizers import Adam, SGD, RMSprop
from keras.layers import Flatten, Dense, Input, Conv2D, MaxPooling2D, Dropout
from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, TimeDistributed
from keras.engine.topology import get_source_inputs
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.objectives import categorical_crossentropy

from keras.models import Model
from keras.utils import generic_utils
from keras.engine import Layer, InputSpec
from keras import initializers, regularizers
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %% [markdown]
# #### Config setting

# %%
class Config:

	def __init__(self):

		# Print the process or not
		self.verbose = True

		# Name of base network
		self.network = 'vgg'

		# Setting for data augmentation
		self.use_horizontal_flips = False
		self.use_vertical_flips = False
		self.rot_90 = False

		# Anchor box scales
    # Note that if im_size is smaller, anchor_box_scales should be scaled
    # Original anchor_box_scales in the paper is [128, 256, 512]
		self.anchor_box_scales = [64, 128, 256] 

		# Anchor box ratios
		self.anchor_box_ratios = [[1, 1], [1./math.sqrt(2), 2./math.sqrt(2)], [2./math.sqrt(2), 1./math.sqrt(2)]]

		# Size to resize the smallest side of the image
		# Original setting in paper is 600. Set to 300 in here to save training time
		self.im_size = 300

		# image channel-wise mean to subtract
		self.img_channel_mean = [103.939, 116.779, 123.68]
		self.img_scaling_factor = 1.0

		# number of ROIs at once
		self.num_rois = 4

		# stride at the RPN (this depends on the network configuration)
		self.rpn_stride = 16

		self.balanced_classes = False

		# scaling the stdev
		self.std_scaling = 4.0
		self.classifier_regr_std = [8.0, 8.0, 4.0, 4.0]

		# overlaps for RPN
		self.rpn_min_overlap = 0.3
		self.rpn_max_overlap = 0.7

		# overlaps for classifier ROIs
		self.classifier_min_overlap = 0.1
		self.classifier_max_overlap = 0.5

		# placeholder for the class mapping, automatically generated by the parser
		self.class_mapping = None

		self.model_path = None

# %% [markdown]
# #### Parser the data from annotation file

# %%
def get_data(input_path):
	"""Parse the data from annotation file
	
	Args:
		input_path: annotation file path

	Returns:
		all_data: list(filepath, width, height, list(bboxes))
		classes_count: dict{key:class_name, value:count_num} 
			e.g. {'Car': 2383, 'Mobile phone': 1108, 'Person': 3745}
		class_mapping: dict{key:class_name, value: idx}
			e.g. {'Car': 0, 'Mobile phone': 1, 'Person': 2}
	"""
	found_bg = False
	all_imgs = {}

	classes_count = {}

	class_mapping = {}

	visualise = True

	i = 1
	
	with open(input_path,'r') as f:

		print('Parsing annotation files')

		for line in f:

			# Print process
			sys.stdout.write('\r'+'idx=' + str(i))
			i += 1

			line_split = line.strip().split(',')

			# Make sure the info saved in annotation file matching the format (path_filename, x1, y1, x2, y2, class_name)
			# Note:
			#	One path_filename might has several classes (class_name)
			#	x1, y1, x2, y2 are the pixel value of the origial image, not the ratio value
			#	(x1, y1) top left coordinates; (x2, y2) bottom right coordinates
			#   x1,y1-------------------
			#	|						|
			#	|						|
			#	|						|
			#	|						|
			#	---------------------x2,y2

			(filename,x1,y1,x2,y2,class_name) = line_split

			if class_name not in classes_count:
				classes_count[class_name] = 1
			else:
				classes_count[class_name] += 1

			if class_name not in class_mapping:
				if class_name == 'bg' and found_bg == False:
					print('Found class name with special name bg. Will be treated as a background region (this is usually for hard negative mining).')
					found_bg = True
				class_mapping[class_name] = len(class_mapping)

			if filename not in all_imgs:
				all_imgs[filename] = {}
				
				img = io.imread(filename)
				(rows,cols) = img.shape[:2]
				all_imgs[filename]['filepath'] = filename
				all_imgs[filename]['width'] = cols
				all_imgs[filename]['height'] = rows
				all_imgs[filename]['bboxes'] = []
				# if np.random.randint(0,6) > 0:
				# 	all_imgs[filename]['imageset'] = 'trainval'
				# else:
				# 	all_imgs[filename]['imageset'] = 'test'
			x1 , x2 , y1 , y2 = int(float(x1)*cols) , int(float(x2)*cols) , int(float(y1)*rows) , int(float(y2)*rows)

			all_imgs[filename]['bboxes'].append({'class': class_name, 'x1': x1, 'x2': x2, 'y1': y1, 'y2': y2 })


		all_data = []
		for key in all_imgs:
			all_data.append(all_imgs[key])
		
		# make sure the bg class is last in the list
		if found_bg:
			if class_mapping['bg'] != len(class_mapping) - 1:
				key_to_switch = [key for key in class_mapping.keys() if class_mapping[key] == len(class_mapping)-1][0]
				val_to_switch = class_mapping['bg']
				class_mapping['bg'] = len(class_mapping) - 1
				class_mapping[key_to_switch] = val_to_switch
		
		return all_data, classes_count, class_mapping

# %% [markdown]
# #### Define ROI Pooling Convolutional Layer

# %%
class RoiPoolingConv(Layer):
    '''ROI pooling layer for 2D inputs.
    See Spatial Pyramid Pooling in Deep Convolutional Networks for Visual Recognition,
    K. He, X. Zhang, S. Ren, J. Sun
    # Arguments
        pool_size: int
            Size of pooling region to use. pool_size = 7 will result in a 7x7 region.
        num_rois: number of regions of interest to be used
    # Input shape
        list of two 4D tensors [X_img,X_roi] with shape:
        X_img:
        `(1, rows, cols, channels)`
        X_roi:
        `(1,num_rois,4)` list of rois, with ordering (x,y,w,h)
    # Output shape
        3D tensor with shape:
        `(1, num_rois, channels, pool_size, pool_size)`
    '''
    def __init__(self, pool_size, num_rois, **kwargs):

        self.dim_ordering = K.image_data_format()
        self.pool_size = pool_size
        self.num_rois = num_rois

        super(RoiPoolingConv, self).__init__(**kwargs)

    def build(self, input_shape):
        self.nb_channels = input_shape[0][3]   

    def compute_output_shape(self, input_shape):
        return None, self.num_rois, self.pool_size, self.pool_size, self.nb_channels

    def call(self, x, mask=None):

        assert(len(x) == 2)

        # x[0] is image with shape (rows, cols, channels)
        img = x[0]

        # x[1] is roi with shape (num_rois,4) with ordering (x,y,w,h)
        rois = x[1]

        input_shape = K.shape(img)

        outputs = []

        for roi_idx in range(self.num_rois):

            x = rois[0, roi_idx, 0]
            y = rois[0, roi_idx, 1]
            w = rois[0, roi_idx, 2]
            h = rois[0, roi_idx, 3]

            x = K.cast(x, 'int32')
            y = K.cast(y, 'int32')
            w = K.cast(w, 'int32')
            h = K.cast(h, 'int32')

            # Resized roi of the image to pooling size (7x7)
            rs = tf.image.resize_images(img[:, y:y+h, x:x+w, :], (self.pool_size, self.pool_size))
            outputs.append(rs)
                

        final_output = K.concatenate(outputs, axis=0)

        # Reshape to (1, num_rois, pool_size, pool_size, nb_channels)
        # Might be (1, 4, 7, 7, 3)
        final_output = K.reshape(final_output, (1, self.num_rois, self.pool_size, self.pool_size, self.nb_channels))

        # permute_dimensions is similar to transpose
        final_output = K.permute_dimensions(final_output, (0, 1, 2, 3, 4))

        return final_output
    
    
    def get_config(self):
        config = {'pool_size': self.pool_size,
                  'num_rois': self.num_rois}
        base_config = super(RoiPoolingConv, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# #### Vgg-16 model

# %%
def get_img_output_length(width, height):
    def get_output_length(input_length):
        return input_length//16

    return get_output_length(width), get_output_length(height)    

def nn_base(input_tensor=None, trainable=False):


    input_shape = (None, None, 3)

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    bn_axis = 3

    # Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
    # x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

    return x

# %% [markdown]
# ####  RPN layer

# %%
def rpn_layer(base_layers, num_anchors):
    """Create a rpn layer
        Step1: Pass through the feature map from base layer to a 3x3 512 channels convolutional layer
                Keep the padding 'same' to preserve the feature map's size
        Step2: Pass the step1 to two (1,1) convolutional layer to replace the fully connected layer
                classification layer: num_anchors (9 in here) channels for 0, 1 sigmoid activation output
                regression layer: num_anchors*4 (36 in here) channels for computing the regression of bboxes with linear activation
    Args:
        base_layers: vgg in here
        num_anchors: 9 in here

    Returns:
        [x_class, x_regr, base_layers]
        x_class: classification for whether it's an object
        x_regr: bboxes regression
        base_layers: vgg in here
    """
    x = Conv2D(512, (3, 3), padding='same', activation='relu', kernel_initializer='normal', name='rpn_conv1')(base_layers)

    x_class = Conv2D(num_anchors, (1, 1), activation='sigmoid', kernel_initializer='uniform', name='rpn_out_class')(x)
    x_regr = Conv2D(num_anchors * 4, (1, 1), activation='linear', kernel_initializer='zero', name='rpn_out_regress')(x)

    return [x_class, x_regr, base_layers]

# %% [markdown]
# ####  Classifier layer

# %%
def classifier_layer(base_layers, input_rois, num_rois, nb_classes = 4):
    """Create a classifier layer
    
    Args:
        base_layers: vgg
        input_rois: `(1,num_rois,4)` list of rois, with ordering (x,y,w,h)
        num_rois: number of rois to be processed in one time (4 in here)

    Returns:
        list(out_class, out_regr)
        out_class: classifier layer output
        out_regr: regression layer output
    """

    input_shape = (num_rois,7,7,512)

    pooling_regions = 7

    # out_roi_pool.shape = (1, num_rois, channels, pool_size, pool_size)
    # num_rois (4) 7x7 roi pooling
    out_roi_pool = RoiPoolingConv(pooling_regions, num_rois)([base_layers, input_rois])

    # Flatten the convlutional layer and connected to 2 FC and 2 dropout
    out = TimeDistributed(Flatten(name='flatten'))(out_roi_pool)
    out = TimeDistributed(Dense(4096, activation='relu', name='fc1'))(out)
    out = TimeDistributed(Dropout(0.5))(out)
    out = TimeDistributed(Dense(4096, activation='relu', name='fc2'))(out)
    out = TimeDistributed(Dropout(0.5))(out)

    # There are two output layer
    # out_class: softmax acivation function for classify the class name of the object
    # out_regr: linear activation function for bboxes coordinates regression
    out_class = TimeDistributed(Dense(nb_classes, activation='softmax', kernel_initializer='zero'), name='dense_class_{}'.format(nb_classes))(out)
    # note: no regression target for bg class
    out_regr = TimeDistributed(Dense(4 * (nb_classes-1), activation='linear', kernel_initializer='zero'), name='dense_regress_{}'.format(nb_classes))(out)

    return [out_class, out_regr]

# %% [markdown]
# #### Calculate IoU (Intersection of Union)

# %%
def union(au, bu, area_intersection):
	area_a = (au[2] - au[0]) * (au[3] - au[1])
	area_b = (bu[2] - bu[0]) * (bu[3] - bu[1])
	area_union = area_a + area_b - area_intersection
	return area_union


def intersection(ai, bi):
	x = max(ai[0], bi[0])
	y = max(ai[1], bi[1])
	w = min(ai[2], bi[2]) - x
	h = min(ai[3], bi[3]) - y
	if w < 0 or h < 0:
		return 0
	return w*h


def iou(a, b):
	# a and b should be (x1,y1,x2,y2)

	if a[0] >= a[2] or a[1] >= a[3] or b[0] >= b[2] or b[1] >= b[3]:
		return 0.0

	area_i = intersection(a, b)
	area_u = union(a, b, area_i)

	return float(area_i) / float(area_u + 1e-6)

# %% [markdown]
# #### Calculate the rpn for all anchors of all images

# %%
def calc_rpn(C, img_data, width, height, resized_width, resized_height, img_length_calc_function):
	"""(Important part!) Calculate the rpn for all anchors 
		If feature map has shape 38x50=1900, there are 1900x9=17100 potential anchors
	
	Args:
		C: config
		img_data: augmented image data
		width: original image width (e.g. 600)
		height: original image height (e.g. 800)
		resized_width: resized image width according to C.im_size (e.g. 300)
		resized_height: resized image height according to C.im_size (e.g. 400)
		img_length_calc_function: function to calculate final layer's feature map (of base model) size according to input image size

	Returns:
		y_rpn_cls: list(num_bboxes, y_is_box_valid + y_rpn_overlap)
			y_is_box_valid: 0 or 1 (0 means the box is invalid, 1 means the box is valid)
			y_rpn_overlap: 0 or 1 (0 means the box is not an object, 1 means the box is an object)
		y_rpn_regr: list(num_bboxes, 4*y_rpn_overlap + y_rpn_regr)
			y_rpn_regr: x1,y1,x2,y2 bunding boxes coordinates
	"""
	downscale = float(C.rpn_stride) 
	anchor_sizes = C.anchor_box_scales   # 128, 256, 512
	anchor_ratios = C.anchor_box_ratios  # 1:1, 1:2*sqrt(2), 2*sqrt(2):1
	num_anchors = len(anchor_sizes) * len(anchor_ratios) # 3x3=9

	# calculate the output map size based on the network architecture
	(output_width, output_height) = img_length_calc_function(resized_width, resized_height)

	n_anchratios = len(anchor_ratios)    # 3
	
	# initialise empty output objectives
	y_rpn_overlap = np.zeros((output_height, output_width, num_anchors))
	y_is_box_valid = np.zeros((output_height, output_width, num_anchors))
	y_rpn_regr = np.zeros((output_height, output_width, num_anchors * 4))

	num_bboxes = len(img_data['bboxes'])

	num_anchors_for_bbox = np.zeros(num_bboxes).astype(int)
	best_anchor_for_bbox = -1*np.ones((num_bboxes, 4)).astype(int)
	best_iou_for_bbox = np.zeros(num_bboxes).astype(np.float32)
	best_x_for_bbox = np.zeros((num_bboxes, 4)).astype(int)
	best_dx_for_bbox = np.zeros((num_bboxes, 4)).astype(np.float32)

	# get the GT box coordinates, and resize to account for image resizing
	gta = np.zeros((num_bboxes, 4))
	for bbox_num, bbox in enumerate(img_data['bboxes']):
		# get the GT box coordinates, and resize to account for image resizing
		gta[bbox_num, 0] = bbox['x1'] * (resized_width / float(width))
		gta[bbox_num, 1] = bbox['x2'] * (resized_width / float(width))
		gta[bbox_num, 2] = bbox['y1'] * (resized_height / float(height))
		gta[bbox_num, 3] = bbox['y2'] * (resized_height / float(height))
	
	# rpn ground truth

	for anchor_size_idx in range(len(anchor_sizes)):
		for anchor_ratio_idx in range(n_anchratios):
			anchor_x = anchor_sizes[anchor_size_idx] * anchor_ratios[anchor_ratio_idx][0]
			anchor_y = anchor_sizes[anchor_size_idx] * anchor_ratios[anchor_ratio_idx][1]	
			
			for ix in range(output_width):					
				# x-coordinates of the current anchor box	
				x1_anc = downscale * (ix + 0.5) - anchor_x / 2
				x2_anc = downscale * (ix + 0.5) + anchor_x / 2	
				
				# ignore boxes that go across image boundaries					
				if x1_anc < 0 or x2_anc > resized_width:
					continue
					
				for jy in range(output_height):

					# y-coordinates of the current anchor box
					y1_anc = downscale * (jy + 0.5) - anchor_y / 2
					y2_anc = downscale * (jy + 0.5) + anchor_y / 2

					# ignore boxes that go across image boundaries
					if y1_anc < 0 or y2_anc > resized_height:
						continue

					# bbox_type indicates whether an anchor should be a target
					# Initialize with 'negative'
					bbox_type = 'neg'

					# this is the best IOU for the (x,y) coord and the current anchor
					# note that this is different from the best IOU for a GT bbox
					best_iou_for_loc = 0.0

					for bbox_num in range(num_bboxes):
						
						# get IOU of the current GT box and the current anchor box
						curr_iou = iou([gta[bbox_num, 0], gta[bbox_num, 2], gta[bbox_num, 1], gta[bbox_num, 3]], [x1_anc, y1_anc, x2_anc, y2_anc])
						# calculate the regression targets if they will be needed
						if curr_iou > best_iou_for_bbox[bbox_num] or curr_iou > C.rpn_max_overlap:
							cx = (gta[bbox_num, 0] + gta[bbox_num, 1]) / 2.0
							cy = (gta[bbox_num, 2] + gta[bbox_num, 3]) / 2.0
							cxa = (x1_anc + x2_anc)/2.0
							cya = (y1_anc + y2_anc)/2.0

							# x,y are the center point of ground-truth bbox
							# xa,ya are the center point of anchor bbox (xa=downscale * (ix + 0.5); ya=downscale * (iy+0.5))
							# w,h are the width and height of ground-truth bbox
							# wa,ha are the width and height of anchor bboxe
							# tx = (x - xa) / wa
							# ty = (y - ya) / ha
							# tw = log(w / wa)
							# th = log(h / ha)
							tx = (cx - cxa) / (x2_anc - x1_anc)
							ty = (cy - cya) / (y2_anc - y1_anc)
							tw = np.log((gta[bbox_num, 1] - gta[bbox_num, 0]) / (x2_anc - x1_anc))
							th = np.log((gta[bbox_num, 3] - gta[bbox_num, 2]) / (y2_anc - y1_anc))
						
						if img_data['bboxes'][bbox_num]['class'] != 'bg':

							# all GT boxes should be mapped to an anchor box, so we keep track of which anchor box was best
							if curr_iou > best_iou_for_bbox[bbox_num]:
								best_anchor_for_bbox[bbox_num] = [jy, ix, anchor_ratio_idx, anchor_size_idx]
								best_iou_for_bbox[bbox_num] = curr_iou
								best_x_for_bbox[bbox_num,:] = [x1_anc, x2_anc, y1_anc, y2_anc]
								best_dx_for_bbox[bbox_num,:] = [tx, ty, tw, th]

							# we set the anchor to positive if the IOU is >0.7 (it does not matter if there was another better box, it just indicates overlap)
							if curr_iou > C.rpn_max_overlap:
								bbox_type = 'pos'
								num_anchors_for_bbox[bbox_num] += 1
								# we update the regression layer target if this IOU is the best for the current (x,y) and anchor position
								if curr_iou > best_iou_for_loc:
									best_iou_for_loc = curr_iou
									best_regr = (tx, ty, tw, th)

							# if the IOU is >0.3 and <0.7, it is ambiguous and no included in the objective
							if C.rpn_min_overlap < curr_iou < C.rpn_max_overlap:
								# gray zone between neg and pos
								if bbox_type != 'pos':
									bbox_type = 'neutral'

					# turn on or off outputs depending on IOUs
					if bbox_type == 'neg':
						y_is_box_valid[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 1
						y_rpn_overlap[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 0
					elif bbox_type == 'neutral':
						y_is_box_valid[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 0
						y_rpn_overlap[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 0
					elif bbox_type == 'pos':
						y_is_box_valid[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 1
						y_rpn_overlap[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 1
						start = 4 * (anchor_ratio_idx + n_anchratios * anchor_size_idx)
						y_rpn_regr[jy, ix, start:start+4] = best_regr

	# we ensure that every bbox has at least one positive RPN region

	for idx in range(num_anchors_for_bbox.shape[0]):
		if num_anchors_for_bbox[idx] == 0:
			# no box with an IOU greater than zero ...
			if best_anchor_for_bbox[idx, 0] == -1:
				continue
			y_is_box_valid[
				best_anchor_for_bbox[idx,0], best_anchor_for_bbox[idx,1], best_anchor_for_bbox[idx,2] + n_anchratios *
				best_anchor_for_bbox[idx,3]] = 1
			y_rpn_overlap[
				best_anchor_for_bbox[idx,0], best_anchor_for_bbox[idx,1], best_anchor_for_bbox[idx,2] + n_anchratios *
				best_anchor_for_bbox[idx,3]] = 1
			start = 4 * (best_anchor_for_bbox[idx,2] + n_anchratios * best_anchor_for_bbox[idx,3])
			y_rpn_regr[
				best_anchor_for_bbox[idx,0], best_anchor_for_bbox[idx,1], start:start+4] = best_dx_for_bbox[idx, :]

	y_rpn_overlap = np.transpose(y_rpn_overlap, (2, 0, 1))
	y_rpn_overlap = np.expand_dims(y_rpn_overlap, axis=0)

	y_is_box_valid = np.transpose(y_is_box_valid, (2, 0, 1))
	y_is_box_valid = np.expand_dims(y_is_box_valid, axis=0)

	y_rpn_regr = np.transpose(y_rpn_regr, (2, 0, 1))
	y_rpn_regr = np.expand_dims(y_rpn_regr, axis=0)

	pos_locs = np.where(np.logical_and(y_rpn_overlap[0, :, :, :] == 1, y_is_box_valid[0, :, :, :] == 1))
	neg_locs = np.where(np.logical_and(y_rpn_overlap[0, :, :, :] == 0, y_is_box_valid[0, :, :, :] == 1))

	num_pos = len(pos_locs[0])

	# one issue is that the RPN has many more negative than positive regions, so we turn off some of the negative
	# regions. We also limit it to 256 regions.
	num_regions = 256

	if len(pos_locs[0]) > num_regions/2:
		val_locs = random.sample(range(len(pos_locs[0])), len(pos_locs[0]) - num_regions/2)
		y_is_box_valid[0, pos_locs[0][val_locs], pos_locs[1][val_locs], pos_locs[2][val_locs]] = 0
		num_pos = num_regions/2

	if len(neg_locs[0]) + num_pos > num_regions:
		val_locs = random.sample(range(len(neg_locs[0])), len(neg_locs[0]) - num_pos)
		y_is_box_valid[0, neg_locs[0][val_locs], neg_locs[1][val_locs], neg_locs[2][val_locs]] = 0

	y_rpn_cls = np.concatenate([y_is_box_valid, y_rpn_overlap], axis=1)
	y_rpn_regr = np.concatenate([np.repeat(y_rpn_overlap, 4, axis=1), y_rpn_regr], axis=1)

	return np.copy(y_rpn_cls), np.copy(y_rpn_regr), num_pos

# %% [markdown]
# #### Get new image size and augment the image

# %%
def get_new_img_size(width, height, img_min_side=300):
	if width <= height:
		f = float(img_min_side) / width
		resized_height = int(f * height)
		resized_width = img_min_side
	else:
		f = float(img_min_side) / height
		resized_width = int(f * width)
		resized_height = img_min_side

	return resized_width, resized_height

def augment(img_data, config, augment=True):
	assert 'filepath' in img_data
	assert 'bboxes' in img_data
	assert 'width' in img_data
	assert 'height' in img_data

	img_data_aug = copy.deepcopy(img_data)

	img = io.imread(img_data_aug['filepath'])

	if augment:
		rows, cols = img.shape[:2]

		if config.use_horizontal_flips and np.random.randint(0, 2) == 0:
			img = cv2.flip(img, 1)
			for bbox in img_data_aug['bboxes']:
				x1 = bbox['x1']
				x2 = bbox['x2']
				bbox['x2'] = cols - x1
				bbox['x1'] = cols - x2

		if config.use_vertical_flips and np.random.randint(0, 2) == 0:
			img = cv2.flip(img, 0)
			for bbox in img_data_aug['bboxes']:
				y1 = bbox['y1']
				y2 = bbox['y2']
				bbox['y2'] = rows - y1
				bbox['y1'] = rows - y2

		if config.rot_90:
			angle = np.random.choice([0,90,180,270],1)[0]
			if angle == 270:
				img = np.transpose(img, (1,0,2))
				img = cv2.flip(img, 0)
			elif angle == 180:
				img = cv2.flip(img, -1)
			elif angle == 90:
				img = np.transpose(img, (1,0,2))
				img = cv2.flip(img, 1)
			elif angle == 0:
				pass

			for bbox in img_data_aug['bboxes']:
				x1 = bbox['x1']
				x2 = bbox['x2']
				y1 = bbox['y1']
				y2 = bbox['y2']
				if angle == 270:
					bbox['x1'] = y1
					bbox['x2'] = y2
					bbox['y1'] = cols - x2
					bbox['y2'] = cols - x1
				elif angle == 180:
					bbox['x2'] = cols - x1
					bbox['x1'] = cols - x2
					bbox['y2'] = rows - y1
					bbox['y1'] = rows - y2
				elif angle == 90:
					bbox['x1'] = rows - y2
					bbox['x2'] = rows - y1
					bbox['y1'] = x1
					bbox['y2'] = x2        
				elif angle == 0:
					pass

	img_data_aug['width'] = img.shape[1]
	img_data_aug['height'] = img.shape[0]
	return img_data_aug, img

# %% [markdown]
# #### Generate the ground_truth anchors

# %%
def get_anchor_gt(all_img_data, C, img_length_calc_function, mode='train'):
	""" Yield the ground-truth anchors as Y (labels)
		
	Args:
		all_img_data: list(filepath, width, height, list(bboxes))
		C: config
		img_length_calc_function: function to calculate final layer's feature map (of base model) size according to input image size
		mode: 'train' or 'test'; 'train' mode need augmentation

	Returns:
		x_img: image data after resized and scaling (smallest size = 300px)
		Y: [y_rpn_cls, y_rpn_regr]
		img_data_aug: augmented image data (original image with augmentation)
		debug_img: show image for debug
		num_pos: show number of positive anchors for debug
	"""
	while True:

		for img_data in all_img_data:
			try:

				# read in image, and optionally add augmentation

				if mode == 'train':
					img_data_aug, x_img = augment(img_data, C, augment=True)
				else:
					img_data_aug, x_img = augment(img_data, C, augment=False)

				(width, height) = (img_data_aug['width'], img_data_aug['height'])
				(rows, cols, _) = x_img.shape

				assert cols == width
				assert rows == height

				# get image dimensions for resizing
				(resized_width, resized_height) = get_new_img_size(width, height, C.im_size)

				# resize the image so that smalles side is length = 300px
				x_img = cv2.resize(x_img, (resized_width, resized_height), interpolation=cv2.INTER_CUBIC)
				debug_img = x_img.copy()

				try:
					y_rpn_cls, y_rpn_regr, num_pos = calc_rpn(C, img_data_aug, width, height, resized_width, resized_height, img_length_calc_function)
				except:
					continue

				# Zero-center by mean pixel, and preprocess image

				x_img = x_img[:,:, (2, 1, 0)]  # BGR -> RGB
				x_img = x_img.astype(np.float32)
				x_img[:, :, 0] -= C.img_channel_mean[0]
				x_img[:, :, 1] -= C.img_channel_mean[1]
				x_img[:, :, 2] -= C.img_channel_mean[2]
				x_img /= C.img_scaling_factor

				x_img = np.transpose(x_img, (2, 0, 1))
				x_img = np.expand_dims(x_img, axis=0)

				y_rpn_regr[:, y_rpn_regr.shape[1]//2:, :, :] *= C.std_scaling

				x_img = np.transpose(x_img, (0, 2, 3, 1))
				y_rpn_cls = np.transpose(y_rpn_cls, (0, 2, 3, 1))
				y_rpn_regr = np.transpose(y_rpn_regr, (0, 2, 3, 1))

				yield np.copy(x_img), [np.copy(y_rpn_cls), np.copy(y_rpn_regr)], img_data_aug, debug_img, num_pos

			except Exception as e:
				print(e)
				continue

# %% [markdown]
# #### Define loss functions for all four outputs

# %%
lambda_rpn_regr = 1.0
lambda_rpn_class = 1.0

lambda_cls_regr = 1.0
lambda_cls_class = 1.0

epsilon = 1e-4

# %%
def rpn_loss_regr(num_anchors):
    """Loss function for rpn regression
    Args:
        num_anchors: number of anchors (9 in here)
    Returns:
        Smooth L1 loss function 
                           0.5*x*x (if x_abs < 1)
                           x_abx - 0.5 (otherwise)
    """
    def rpn_loss_regr_fixed_num(y_true, y_pred):

        # x is the difference between true value and predicted vaue
        x = y_true[:, :, :, 4 * num_anchors:] - y_pred

        # absolute value of x
        x_abs = K.abs(x)

        # If x_abs <= 1.0, x_bool = 1
        x_bool = K.cast(K.less_equal(x_abs, 1.0), tf.float32)

        return lambda_rpn_regr * K.sum(
            y_true[:, :, :, :4 * num_anchors] * (x_bool * (0.5 * x * x) + (1 - x_bool) * (x_abs - 0.5))) / K.sum(epsilon + y_true[:, :, :, :4 * num_anchors])

    return rpn_loss_regr_fixed_num


def rpn_loss_cls(num_anchors):
    """Loss function for rpn classification
    Args:
        num_anchors: number of anchors (9 in here)
        y_true[:, :, :, :9]: [0,1,0,0,0,0,0,1,0] means only the second and the eighth box is valid which contains pos or neg anchor => isValid
        y_true[:, :, :, 9:]: [0,1,0,0,0,0,0,0,0] means the second box is pos and eighth box is negative
    Returns:
        lambda * sum((binary_crossentropy(isValid*y_pred,y_true))) / N
    """
    def rpn_loss_cls_fixed_num(y_true, y_pred):

            return lambda_rpn_class * K.sum(y_true[:, :, :, :num_anchors] * K.binary_crossentropy(y_pred[:, :, :, :], y_true[:, :, :, num_anchors:])) / K.sum(epsilon + y_true[:, :, :, :num_anchors])

    return rpn_loss_cls_fixed_num


def class_loss_regr(num_classes):
    """Loss function for rpn regression
    Args:
        num_anchors: number of anchors (9 in here)
    Returns:
        Smooth L1 loss function 
                           0.5*x*x (if x_abs < 1)
                           x_abx - 0.5 (otherwise)
    """
    def class_loss_regr_fixed_num(y_true, y_pred):
        x = y_true[:, :, 4*num_classes:] - y_pred
        x_abs = K.abs(x)
        x_bool = K.cast(K.less_equal(x_abs, 1.0), 'float32')
        return lambda_cls_regr * K.sum(y_true[:, :, :4*num_classes] * (x_bool * (0.5 * x * x) + (1 - x_bool) * (x_abs - 0.5))) / K.sum(epsilon + y_true[:, :, :4*num_classes])
    return class_loss_regr_fixed_num


def class_loss_cls(y_true, y_pred):
    return lambda_cls_class * K.mean(categorical_crossentropy(y_true[0, :, :], y_pred[0, :, :]))

# %%
def non_max_suppression_fast(boxes, probs, overlap_thresh=0.9, max_boxes=300):
    # code used from here: http://www.pyimagesearch.com/2015/02/16/faster-non-maximum-suppression-python/
    # if there are no boxes, return an empty list

    # Process explanation:
    #   Step 1: Sort the probs list
    #   Step 2: Find the larget prob 'Last' in the list and save it to the pick list
    #   Step 3: Calculate the IoU with 'Last' box and other boxes in the list. If the IoU is larger than overlap_threshold, delete the box from list
    #   Step 4: Repeat step 2 and step 3 until there is no item in the probs list 
    if len(boxes) == 0:
        return []

    # grab the coordinates of the bounding boxes
    x1 = boxes[:, 0]
    y1 = boxes[:, 1]
    x2 = boxes[:, 2]
    y2 = boxes[:, 3]

    np.testing.assert_array_less(x1, x2)
    np.testing.assert_array_less(y1, y2)

    # if the bounding boxes integers, convert them to floats --
    # this is important since we'll be doing a bunch of divisions
    if boxes.dtype.kind == "i":
        boxes = boxes.astype("float")

    # initialize the list of picked indexes	
    pick = []

    # calculate the areas
    area = (x2 - x1) * (y2 - y1)

    # sort the bounding boxes 
    idxs = np.argsort(probs)

    # keep looping while some indexes still remain in the indexes
    # list
    while len(idxs) > 0:
        # grab the last index in the indexes list and add the
        # index value to the list of picked indexes
        last = len(idxs) - 1
        i = idxs[last]
        pick.append(i)

        # find the intersection

        xx1_int = np.maximum(x1[i], x1[idxs[:last]])
        yy1_int = np.maximum(y1[i], y1[idxs[:last]])
        xx2_int = np.minimum(x2[i], x2[idxs[:last]])
        yy2_int = np.minimum(y2[i], y2[idxs[:last]])

        ww_int = np.maximum(0, xx2_int - xx1_int)
        hh_int = np.maximum(0, yy2_int - yy1_int)

        area_int = ww_int * hh_int

        # find the union
        area_union = area[i] + area[idxs[:last]] - area_int

        # compute the ratio of overlap
        overlap = area_int/(area_union + 1e-6)

        # delete all indexes from the index list that have
        idxs = np.delete(idxs, np.concatenate(([last],
            np.where(overlap > overlap_thresh)[0])))

        if len(pick) >= max_boxes:
            break

    # return only the bounding boxes that were picked using the integer data type
    boxes = boxes[pick].astype("int")
    probs = probs[pick]
    return boxes, probs

def apply_regr_np(X, T):
    """Apply regression layer to all anchors in one feature map

    Args:
        X: shape=(4, 18, 25) the current anchor type for all points in the feature map
        T: regression layer shape=(4, 18, 25)

    Returns:
        X: regressed position and size for current anchor
    """
    try:
        x = X[0, :, :]
        y = X[1, :, :]
        w = X[2, :, :]
        h = X[3, :, :]

        tx = T[0, :, :]
        ty = T[1, :, :]
        tw = T[2, :, :]
        th = T[3, :, :]

        cx = x + w/2.
        cy = y + h/2.
        cx1 = tx * w + cx
        cy1 = ty * h + cy

        w1 = np.exp(tw.astype(np.float64)) * w
        h1 = np.exp(th.astype(np.float64)) * h
        x1 = cx1 - w1/2.
        y1 = cy1 - h1/2.

        x1 = np.round(x1)
        y1 = np.round(y1)
        w1 = np.round(w1)
        h1 = np.round(h1)
        return np.stack([x1, y1, w1, h1])
    except Exception as e:
        print(e)
        return X
    
def apply_regr(x, y, w, h, tx, ty, tw, th):
    # Apply regression to x, y, w and h
    try:
        cx = x + w/2.
        cy = y + h/2.
        cx1 = tx * w + cx
        cy1 = ty * h + cy
        w1 = math.exp(tw) * w
        h1 = math.exp(th) * h
        x1 = cx1 - w1/2.
        y1 = cy1 - h1/2.
        x1 = int(round(x1))
        y1 = int(round(y1))
        w1 = int(round(w1))
        h1 = int(round(h1))

        return x1, y1, w1, h1

    except ValueError:
        return x, y, w, h
    except OverflowError:
        return x, y, w, h
    except Exception as e:
        print(e)
        return x, y, w, h

def calc_iou(R, img_data, C, class_mapping):
    """Converts from (x1,y1,x2,y2) to (x,y,w,h) format

    Args:
        R: bboxes, probs
    """
    bboxes = img_data['bboxes']
    (width, height) = (img_data['width'], img_data['height'])
    # get image dimensions for resizing
    (resized_width, resized_height) = get_new_img_size(width, height, C.im_size)

    gta = np.zeros((len(bboxes), 4))

    for bbox_num, bbox in enumerate(bboxes):
        # get the GT box coordinates, and resize to account for image resizing
        # gta[bbox_num, 0] = (40 * (600 / 800)) / 16 = int(round(1.875)) = 2 (x in feature map)
        gta[bbox_num, 0] = int(round(bbox['x1'] * (resized_width / float(width))/C.rpn_stride))
        gta[bbox_num, 1] = int(round(bbox['x2'] * (resized_width / float(width))/C.rpn_stride))
        gta[bbox_num, 2] = int(round(bbox['y1'] * (resized_height / float(height))/C.rpn_stride))
        gta[bbox_num, 3] = int(round(bbox['y2'] * (resized_height / float(height))/C.rpn_stride))

    x_roi = []
    y_class_num = []
    y_class_regr_coords = []
    y_class_regr_label = []
    IoUs = [] # for debugging only

    # R.shape[0]: number of bboxes (=300 from non_max_suppression)
    for ix in range(R.shape[0]):
        (x1, y1, x2, y2) = R[ix, :]
        x1 = int(round(x1))
        y1 = int(round(y1))
        x2 = int(round(x2))
        y2 = int(round(y2))

        best_iou = 0.0
        best_bbox = -1
        # Iterate through all the ground-truth bboxes to calculate the iou
        for bbox_num in range(len(bboxes)):
            curr_iou = iou([gta[bbox_num, 0], gta[bbox_num, 2], gta[bbox_num, 1], gta[bbox_num, 3]], [x1, y1, x2, y2])

            # Find out the corresponding ground-truth bbox_num with larget iou
            if curr_iou > best_iou:
                best_iou = curr_iou
                best_bbox = bbox_num

        if best_iou < C.classifier_min_overlap:
                continue
        else:
            w = x2 - x1
            h = y2 - y1
            x_roi.append([x1, y1, w, h])
            IoUs.append(best_iou)

            if C.classifier_min_overlap <= best_iou < C.classifier_max_overlap:
                # hard negative example
                cls_name = 'bg'
            elif C.classifier_max_overlap <= best_iou:
                cls_name = bboxes[best_bbox]['class']
                cxg = (gta[best_bbox, 0] + gta[best_bbox, 1]) / 2.0
                cyg = (gta[best_bbox, 2] + gta[best_bbox, 3]) / 2.0

                cx = x1 + w / 2.0
                cy = y1 + h / 2.0

                tx = (cxg - cx) / float(w)
                ty = (cyg - cy) / float(h)
                tw = np.log((gta[best_bbox, 1] - gta[best_bbox, 0]) / float(w))
                th = np.log((gta[best_bbox, 3] - gta[best_bbox, 2]) / float(h))
            else:
                print('roi = {}'.format(best_iou))
                raise RuntimeError

        class_num = class_mapping[cls_name]
        class_label = len(class_mapping) * [0]
        class_label[class_num] = 1
        y_class_num.append(copy.deepcopy(class_label))
        coords = [0] * 4 * (len(class_mapping) - 1)
        labels = [0] * 4 * (len(class_mapping) - 1)
        if cls_name != 'bg':
            label_pos = 4 * class_num
            sx, sy, sw, sh = C.classifier_regr_std
            coords[label_pos:4+label_pos] = [sx*tx, sy*ty, sw*tw, sh*th]
            labels[label_pos:4+label_pos] = [1, 1, 1, 1]
            y_class_regr_coords.append(copy.deepcopy(coords))
            y_class_regr_label.append(copy.deepcopy(labels))
        else:
            y_class_regr_coords.append(copy.deepcopy(coords))
            y_class_regr_label.append(copy.deepcopy(labels))

    if len(x_roi) == 0:
        return None, None, None, None

    # bboxes that iou > C.classifier_min_overlap for all gt bboxes in 300 non_max_suppression bboxes
    X = np.array(x_roi)
    # one hot code for bboxes from above => x_roi (X)
    Y1 = np.array(y_class_num)
    # corresponding labels and corresponding gt bboxes
    Y2 = np.concatenate([np.array(y_class_regr_label),np.array(y_class_regr_coords)],axis=1)

    return np.expand_dims(X, axis=0), np.expand_dims(Y1, axis=0), np.expand_dims(Y2, axis=0), IoUs

# %%
def rpn_to_roi(rpn_layer, regr_layer, C, dim_ordering, use_regr=True, max_boxes=300,overlap_thresh=0.9):
	"""Convert rpn layer to roi bboxes

	Args: (num_anchors = 9)
		rpn_layer: output layer for rpn classification 
			shape (1, feature_map.height, feature_map.width, num_anchors)
			Might be (1, 18, 25, 18) if resized image is 400 width and 300
		regr_layer: output layer for rpn regression
			shape (1, feature_map.height, feature_map.width, num_anchors)
			Might be (1, 18, 25, 72) if resized image is 400 width and 300
		C: config
		use_regr: Wether to use bboxes regression in rpn
		max_boxes: max bboxes number for non-max-suppression (NMS)
		overlap_thresh: If iou in NMS is larger than this threshold, drop the box

	Returns:
		result: boxes from non-max-suppression (shape=(300, 4))
			boxes: coordinates for bboxes (on the feature map)
	"""
	regr_layer = regr_layer / C.std_scaling

	anchor_sizes = C.anchor_box_scales   # (3 in here)
	anchor_ratios = C.anchor_box_ratios  # (3 in here)

	assert rpn_layer.shape[0] == 1

	(rows, cols) = rpn_layer.shape[1:3]

	curr_layer = 0

	# A.shape = (4, feature_map.height, feature_map.width, num_anchors) 
	# Might be (4, 18, 25, 18) if resized image is 400 width and 300
	# A is the coordinates for 9 anchors for every point in the feature map 
	# => all 18x25x9=4050 anchors cooridnates
	A = np.zeros((4, rpn_layer.shape[1], rpn_layer.shape[2], rpn_layer.shape[3]))

	for anchor_size in anchor_sizes:
		for anchor_ratio in anchor_ratios:
			# anchor_x = (128 * 1) / 16 = 8  => width of current anchor
			# anchor_y = (128 * 2) / 16 = 16 => height of current anchor
			anchor_x = (anchor_size * anchor_ratio[0])/C.rpn_stride
			anchor_y = (anchor_size * anchor_ratio[1])/C.rpn_stride
			
			# curr_layer: 0~8 (9 anchors)
			# the Kth anchor of all position in the feature map (9th in total)
			regr = regr_layer[0, :, :, 4 * curr_layer:4 * curr_layer + 4] # shape => (18, 25, 4)
			regr = np.transpose(regr, (2, 0, 1)) # shape => (4, 18, 25)

			# Create 18x25 mesh grid
			# For every point in x, there are all the y points and vice versa
			# X.shape = (18, 25)
			# Y.shape = (18, 25)
			X, Y = np.meshgrid(np.arange(cols),np. arange(rows))

			# Calculate anchor position and size for each feature map point
			A[0, :, :, curr_layer] = X - anchor_x/2 # Top left x coordinate
			A[1, :, :, curr_layer] = Y - anchor_y/2 # Top left y coordinate
			A[2, :, :, curr_layer] = anchor_x       # width of current anchor
			A[3, :, :, curr_layer] = anchor_y       # height of current anchor

			# Apply regression to x, y, w and h if there is rpn regression layer
			if use_regr:
				A[:, :, :, curr_layer] = apply_regr_np(A[:, :, :, curr_layer], regr)

			# Avoid width and height exceeding 1
			A[2, :, :, curr_layer] = np.maximum(1, A[2, :, :, curr_layer])
			A[3, :, :, curr_layer] = np.maximum(1, A[3, :, :, curr_layer])

			# Convert (x, y , w, h) to (x1, y1, x2, y2)
			# x1, y1 is top left coordinate
			# x2, y2 is bottom right coordinate
			A[2, :, :, curr_layer] += A[0, :, :, curr_layer]
			A[3, :, :, curr_layer] += A[1, :, :, curr_layer]

			# Avoid bboxes drawn outside the feature map
			A[0, :, :, curr_layer] = np.maximum(0, A[0, :, :, curr_layer])
			A[1, :, :, curr_layer] = np.maximum(0, A[1, :, :, curr_layer])
			A[2, :, :, curr_layer] = np.minimum(cols-1, A[2, :, :, curr_layer])
			A[3, :, :, curr_layer] = np.minimum(rows-1, A[3, :, :, curr_layer])

			curr_layer += 1

	all_boxes = np.reshape(A.transpose((0, 3, 1, 2)), (4, -1)).transpose((1, 0))  # shape=(4050, 4)
	all_probs = rpn_layer.transpose((0, 3, 1, 2)).reshape((-1))                   # shape=(4050,)

	x1 = all_boxes[:, 0]
	y1 = all_boxes[:, 1]
	x2 = all_boxes[:, 2]
	y2 = all_boxes[:, 3]

	# Find out the bboxes which is illegal and delete them from bboxes list
	idxs = np.where((x1 - x2 >= 0) | (y1 - y2 >= 0))

	all_boxes = np.delete(all_boxes, idxs, 0)
	all_probs = np.delete(all_probs, idxs, 0)

	# Apply non_max_suppression
	# Only extract the bboxes. Don't need rpn probs in the later process
	result = non_max_suppression_fast(all_boxes, all_probs, overlap_thresh=overlap_thresh, max_boxes=max_boxes)[0]

	return result

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### Start training

# %%
base_path = 'drive/My Drive/cohort/Faster_RCNN'

train_path =  'drive/My Drive/cohort/Dataset/Open Images Dataset v4 (Bounding Boxes)/annotation.txt' # Training data (annotation file)

num_rois = 4 # Number of RoIs to process at once.

# Augmentation flag
horizontal_flips = True # Augment with horizontal flips in training. 
vertical_flips = True   # Augment with vertical flips in training. 
rot_90 = True           # Augment with 90 degree rotations in training. 

output_weight_path = os.path.join(base_path, 'model/model_frcnn_vgg.hdf5')

record_path = os.path.join(base_path, 'model/record.csv') # Record data (used to save the losses, classification accuracy and mean average precision)

base_weight_path = os.path.join(base_path, 'model/vgg16_weights_tf_dim_ordering_tf_kernels.h5')

config_output_filename = os.path.join(base_path, 'model_vgg_config.pickle')

# %%
# Create the config
C = Config()

C.use_horizontal_flips = horizontal_flips
C.use_vertical_flips = vertical_flips
C.rot_90 = rot_90

C.record_path = record_path
C.model_path = output_weight_path
C.num_rois = num_rois

C.base_net_weights = base_weight_path

# %%
#--------------------------------------------------------#
# This step will spend some time to load the data        #
#--------------------------------------------------------#
st = time.time()
train_imgs, classes_count, class_mapping = get_data(train_path)
print()
print('Spend %0.2f mins to load the data' % ((time.time()-st)/60) )
# Out:
# Parsing annotation files
# idx=10718
# Spend 37.02 mins to load the data

# %%
if 'bg' not in classes_count:
	classes_count['bg'] = 0
	class_mapping['bg'] = len(class_mapping)
# e.g.
#    classes_count: {'Car': 2383, 'Mobile phone': 1108, 'Person': 3745, 'bg': 0}
#    class_mapping: {'Person': 0, 'Car': 1, 'Mobile phone': 2, 'bg': 3}
C.class_mapping = class_mapping

print('Training images per class:')
pprint.pprint(classes_count)
print('Num classes (including bg) = {}'.format(len(classes_count)))
print(class_mapping)

# Save the configuration
with open(config_output_filename, 'wb') as config_f:
	pickle.dump(C,config_f)
	print('Config has been written to {}, and can be loaded when testing to ensure correct results'.format(config_output_filename))
# Out:
# Training images per class:
# {'Person': 6856, 'Stop sign': 318, 'Traffic sign': 3544, 'bg': 0}
# Num classes (including bg) = 4
# {'Person': 0, 'Traffic sign': 1, 'Stop sign': 2, 'bg': 3}
# Config has been written to drive/My Drive/cohort/Faster_RCNN/model_vgg_config.pickle, and can be loaded when testing to ensure correct results

# %%
# Shuffle the images with seed
random.seed(1)
random.shuffle(train_imgs)

print('Num train samples (images) {}'.format(len(train_imgs)))
# Out:
# Num train samples (images) 3498

# %%
# Get train data generator which generate X, Y, image_data
data_gen_train = get_anchor_gt(train_imgs, C, get_img_output_length, mode='train')

# %% [markdown]
# #### Explore 'data_gen_train'
#
# data_gen_train is an **generator**, so we get the data by calling **next(data_gen_train)**

# %%
X, Y, image_data, debug_img, debug_num_pos = next(data_gen_train)

# %%
print('Original image: height=%d width=%d'%(image_data['height'], image_data['width']))
print('Resized image:  height=%d width=%d C.im_size=%d'%(X.shape[1], X.shape[2], C.im_size))
print('Feature map size: height=%d width=%d C.rpn_stride=%d'%(Y[0].shape[1], Y[0].shape[2], C.rpn_stride))
print(X.shape)
print(str(len(Y))+" includes 'y_rpn_cls' and 'y_rpn_regr'")
print('Shape of y_rpn_cls {}'.format(Y[0].shape))
print('Shape of y_rpn_regr {}'.format(Y[1].shape))
print(image_data)

print('Number of positive anchors for this image: %d' % (debug_num_pos))
if debug_num_pos==0:
    gt_x1, gt_x2 = image_data['bboxes'][0]['x1']*(X.shape[2]/image_data['height']), image_data['bboxes'][0]['x2']*(X.shape[2]/image_data['height'])
    gt_y1, gt_y2 = image_data['bboxes'][0]['y1']*(X.shape[1]/image_data['width']), image_data['bboxes'][0]['y2']*(X.shape[1]/image_data['width'])
    gt_x1, gt_y1, gt_x2, gt_y2 = int(gt_x1), int(gt_y1), int(gt_x2), int(gt_y2)

    img = debug_img.copy()
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    color = (0, 255, 0)
    cv2.putText(img, 'gt bbox', (gt_x1, gt_y1-5), cv2.FONT_HERSHEY_DUPLEX, 0.7, color, 1)
    cv2.rectangle(img, (gt_x1, gt_y1), (gt_x2, gt_y2), color, 2)
    cv2.circle(img, (int((gt_x1+gt_x2)/2), int((gt_y1+gt_y2)/2)), 3, color, -1)

    plt.grid()
    plt.imshow(img)
    plt.show()
else:
    cls = Y[0][0]
    pos_cls = np.where(cls==1)
    print(pos_cls)
    regr = Y[1][0]
    pos_regr = np.where(regr==1)
    print(pos_regr)
    print('y_rpn_cls for possible pos anchor: {}'.format(cls[pos_cls[0][0],pos_cls[1][0],:]))
    print('y_rpn_regr for positive anchor: {}'.format(regr[pos_regr[0][0],pos_regr[1][0],:]))

    gt_x1, gt_x2 = image_data['bboxes'][0]['x1']*(X.shape[2]/image_data['width']), image_data['bboxes'][0]['x2']*(X.shape[2]/image_data['width'])
    gt_y1, gt_y2 = image_data['bboxes'][0]['y1']*(X.shape[1]/image_data['height']), image_data['bboxes'][0]['y2']*(X.shape[1]/image_data['height'])
    gt_x1, gt_y1, gt_x2, gt_y2 = int(gt_x1), int(gt_y1), int(gt_x2), int(gt_y2)

    img = debug_img.copy()
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    color = (0, 255, 0)
    #   cv2.putText(img, 'gt bbox', (gt_x1, gt_y1-5), cv2.FONT_HERSHEY_DUPLEX, 0.7, color, 1)
    cv2.rectangle(img, (gt_x1, gt_y1), (gt_x2, gt_y2), color, 2)
    cv2.circle(img, (int((gt_x1+gt_x2)/2), int((gt_y1+gt_y2)/2)), 3, color, -1)

    # Add text
    textLabel = 'gt bbox'
    (retval,baseLine) = cv2.getTextSize(textLabel,cv2.FONT_HERSHEY_COMPLEX,0.5,1)
    textOrg = (gt_x1, gt_y1+5)
    cv2.rectangle(img, (textOrg[0] - 5, textOrg[1]+baseLine - 5), (textOrg[0]+retval[0] + 5, textOrg[1]-retval[1] - 5), (0, 0, 0), 2)
    cv2.rectangle(img, (textOrg[0] - 5,textOrg[1]+baseLine - 5), (textOrg[0]+retval[0] + 5, textOrg[1]-retval[1] - 5), (255, 255, 255), -1)
    cv2.putText(img, textLabel, textOrg, cv2.FONT_HERSHEY_DUPLEX, 0.5, (0, 0, 0), 1)

    # Draw positive anchors according to the y_rpn_regr
    for i in range(debug_num_pos):

        color = (100+i*(155/4), 0, 100+i*(155/4))

        idx = pos_regr[2][i*4]/4
        anchor_size = C.anchor_box_scales[int(idx/3)]
        anchor_ratio = C.anchor_box_ratios[2-int((idx+1)%3)]

        center = (pos_regr[1][i*4]*C.rpn_stride, pos_regr[0][i*4]*C.rpn_stride)
        print('Center position of positive anchor: ', center)
        cv2.circle(img, center, 3, color, -1)
        anc_w, anc_h = anchor_size*anchor_ratio[0], anchor_size*anchor_ratio[1]
        cv2.rectangle(img, (center[0]-int(anc_w/2), center[1]-int(anc_h/2)), (center[0]+int(anc_w/2), center[1]+int(anc_h/2)), color, 2)
#         cv2.putText(img, 'pos anchor bbox '+str(i+1), (center[0]-int(anc_w/2), center[1]-int(anc_h/2)-5), cv2.FONT_HERSHEY_DUPLEX, 0.5, color, 1)

print('Green bboxes is ground-truth bbox. Others are positive anchors')
plt.figure(figsize=(8,8))
plt.grid()
plt.imshow(img)
plt.show()
# Out:
# Original image: height=1024 width=768
# Resized image:  height=400 width=300 C.im_size=300
# Feature map size: height=25 width=18 C.rpn_stride=16
# (1, 400, 300, 3)
# 2 includes 'y_rpn_cls' and 'y_rpn_regr'
# Shape of y_rpn_cls (1, 25, 18, 18)
# Shape of y_rpn_regr (1, 25, 18, 72)
# {'filepath': 'https://requestor-proxy.figure-eight.com/figure_eight_datasets/open-images/train/8fe4821aa144ff33.jpg', 'width': 768, 'height': 1024, 'bboxes': [{'class': 'Stop sign', 'x1': 449, 'x2': 436, 'y1': 647, 'y2': 570}, {'class': 'Stop sign', 'x1': 453, 'x2': 282, 'y1': 854, 'y2': 568}]}
# Number of positive anchors for this image: 0
# Green bboxes is ground-truth bbox. Others are positive anchors

# %% [markdown]
# #### Build the model

# %%
input_shape_img = (None, None, 3)

img_input = Input(shape=input_shape_img)
roi_input = Input(shape=(None, 4))

# define the base network (VGG here, can be Resnet50, Inception, etc)
shared_layers = nn_base(img_input, trainable=True)

# %%
# define the RPN, built on the base layers
num_anchors = len(C.anchor_box_scales) * len(C.anchor_box_ratios) # 9
rpn = rpn_layer(shared_layers, num_anchors)

classifier = classifier_layer(shared_layers, roi_input, C.num_rois, nb_classes=len(classes_count))

model_rpn = Model(img_input, rpn[:2])
model_classifier = Model([img_input, roi_input], classifier)

# this is a model that holds both the RPN and the classifier, used to load/save weights for the models
model_all = Model([img_input, roi_input], rpn[:2] + classifier)

# Because the google colab can only run the session several hours one time (then you need to connect again), 
# we need to save the model and load the model to continue training
if not os.path.isfile(C.model_path):
    #If this is the begin of the training, load the pre-traind base network such as vgg-16
    try:
        print('This is the first time of your training')
        print('loading weights from {}'.format(C.base_net_weights))
        model_rpn.load_weights(C.base_net_weights, by_name=True)
        model_classifier.load_weights(C.base_net_weights, by_name=True)
    except:
        print('Could not load pretrained model weights. Weights can be found in the keras application folder \
            https://github.com/fchollet/keras/tree/master/keras/applications')
    
    # Create the record.csv file to record losses, acc and mAP
    record_df = pd.DataFrame(columns=['mean_overlapping_bboxes', 'class_acc', 'loss_rpn_cls', 'loss_rpn_regr', 'loss_class_cls', 'loss_class_regr', 'curr_loss', 'elapsed_time', 'mAP'])
else:
    # If this is a continued training, load the trained model from before
    print('Continue training based on previous trained model')
    print('Loading weights from {}'.format(C.model_path))
    model_rpn.load_weights(C.model_path, by_name=True)
    model_classifier.load_weights(C.model_path, by_name=True)
    
    # Load the records
    record_df = pd.read_csv(record_path)

    r_mean_overlapping_bboxes = record_df['mean_overlapping_bboxes']
    r_class_acc = record_df['class_acc']
    r_loss_rpn_cls = record_df['loss_rpn_cls']
    r_loss_rpn_regr = record_df['loss_rpn_regr']
    r_loss_class_cls = record_df['loss_class_cls']
    r_loss_class_regr = record_df['loss_class_regr']
    r_curr_loss = record_df['curr_loss']
    r_elapsed_time = record_df['elapsed_time']
    r_mAP = record_df['mAP']

    print('Already train %dK batches'% (len(record_df)))
# Out:
# This is the first time of your training
# loading weights from drive/My Drive/cohort/Faster_RCNN/model/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# Could not load pretrained model weights. Weights can be found in the keras application folder             https://github.com/fchollet/keras/tree/master/keras/applications

# %%
optimizer = Adam(lr=1e-5)
optimizer_classifier = Adam(lr=1e-5)
model_rpn.compile(optimizer=optimizer, loss=[rpn_loss_cls(num_anchors), rpn_loss_regr(num_anchors)])
model_classifier.compile(optimizer=optimizer_classifier, loss=[class_loss_cls, class_loss_regr(len(classes_count)-1)], metrics={'dense_class_{}'.format(len(classes_count)): 'accuracy'})
model_all.compile(optimizer='sgd', loss='mae')

# %%
# Training setting
total_epochs = len(record_df)
r_epochs = len(record_df)

epoch_length = 250
num_epochs = 50
iter_num = 0

total_epochs += num_epochs

losses = np.zeros((epoch_length, 5))
rpn_accuracy_rpn_monitor = []
rpn_accuracy_for_epoch = []

if len(record_df)==0:
    best_loss = np.Inf
else:
    best_loss = np.min(r_curr_loss)

# %%
print(len(record_df))
# Out:
# 0

# %%
start_time = time.time()
for epoch_num in range(num_epochs):

    progbar = generic_utils.Progbar(epoch_length)
    print('Epoch {}/{}'.format(r_epochs + 1, total_epochs))
    
    r_epochs += 1

    while True:
        try:

            if len(rpn_accuracy_rpn_monitor) == epoch_length and C.verbose:
                mean_overlapping_bboxes = float(sum(rpn_accuracy_rpn_monitor))/len(rpn_accuracy_rpn_monitor)
                rpn_accuracy_rpn_monitor = []
#                 print('Average number of overlapping bounding boxes from RPN = {} for {} previous iterations'.format(mean_overlapping_bboxes, epoch_length))
                if mean_overlapping_bboxes == 0:
                    print('RPN is not producing bounding boxes that overlap the ground truth boxes. Check RPN settings or keep training.')

            # Generate X (x_img) and label Y ([y_rpn_cls, y_rpn_regr])
            X, Y, img_data, debug_img, debug_num_pos = next(data_gen_train)

            # Train rpn model and get loss value [_, loss_rpn_cls, loss_rpn_regr]
            loss_rpn = model_rpn.train_on_batch(X, Y)

            # Get predicted rpn from rpn model [rpn_cls, rpn_regr]
            P_rpn = model_rpn.predict_on_batch(X)

            # R: bboxes (shape=(300,4))
            # Convert rpn layer to roi bboxes
            R = rpn_to_roi(P_rpn[0], P_rpn[1], C, K.image_data_format(), use_regr=True, overlap_thresh=0.7, max_boxes=300)
            
            # note: calc_iou converts from (x1,y1,x2,y2) to (x,y,w,h) format
            # X2: bboxes that iou > C.classifier_min_overlap for all gt bboxes in 300 non_max_suppression bboxes
            # Y1: one hot code for bboxes from above => x_roi (X)
            # Y2: corresponding labels and corresponding gt bboxes
            X2, Y1, Y2, IouS = calc_iou(R, img_data, C, class_mapping)

            # If X2 is None means there are no matching bboxes
            if X2 is None:
                rpn_accuracy_rpn_monitor.append(0)
                rpn_accuracy_for_epoch.append(0)
                continue
            
            # Find out the positive anchors and negative anchors
            neg_samples = np.where(Y1[0, :, -1] == 1)
            pos_samples = np.where(Y1[0, :, -1] == 0)

            if len(neg_samples) > 0:
                neg_samples = neg_samples[0]
            else:
                neg_samples = []

            if len(pos_samples) > 0:
                pos_samples = pos_samples[0]
            else:
                pos_samples = []

            rpn_accuracy_rpn_monitor.append(len(pos_samples))
            rpn_accuracy_for_epoch.append((len(pos_samples)))

            if C.num_rois > 1:
                # If number of positive anchors is larger than 4//2 = 2, randomly choose 2 pos samples
                if len(pos_samples) < C.num_rois//2:
                    selected_pos_samples = pos_samples.tolist()
                else:
                    selected_pos_samples = np.random.choice(pos_samples, C.num_rois//2, replace=False).tolist()
                
                # Randomly choose (num_rois - num_pos) neg samples
                try:
                    selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace=False).tolist()
                except:
                    selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace=True).tolist()
                
                # Save all the pos and neg samples in sel_samples
                sel_samples = selected_pos_samples + selected_neg_samples
            else:
                # in the extreme case where num_rois = 1, we pick a random pos or neg sample
                selected_pos_samples = pos_samples.tolist()
                selected_neg_samples = neg_samples.tolist()
                if np.random.randint(0, 2):
                    sel_samples = random.choice(neg_samples)
                else:
                    sel_samples = random.choice(pos_samples)

            # training_data: [X, X2[:, sel_samples, :]]
            # labels: [Y1[:, sel_samples, :], Y2[:, sel_samples, :]]
            #  X                     => img_data resized image
            #  X2[:, sel_samples, :] => num_rois (4 in here) bboxes which contains selected neg and pos
            #  Y1[:, sel_samples, :] => one hot encode for num_rois bboxes which contains selected neg and pos
            #  Y2[:, sel_samples, :] => labels and gt bboxes for num_rois bboxes which contains selected neg and pos
            loss_class = model_classifier.train_on_batch([X, X2[:, sel_samples, :]], [Y1[:, sel_samples, :], Y2[:, sel_samples, :]])

            losses[iter_num, 0] = loss_rpn[1]
            losses[iter_num, 1] = loss_rpn[2]

            losses[iter_num, 2] = loss_class[1]
            losses[iter_num, 3] = loss_class[2]
            losses[iter_num, 4] = loss_class[3]

            iter_num += 1

            progbar.update(iter_num, [('rpn_cls', np.mean(losses[:iter_num, 0])), ('rpn_regr', np.mean(losses[:iter_num, 1])),
                                      ('final_cls', np.mean(losses[:iter_num, 2])), ('final_regr', np.mean(losses[:iter_num, 3]))])

            if iter_num == epoch_length:
                loss_rpn_cls = np.mean(losses[:, 0])
                loss_rpn_regr = np.mean(losses[:, 1])
                loss_class_cls = np.mean(losses[:, 2])
                loss_class_regr = np.mean(losses[:, 3])
                class_acc = np.mean(losses[:, 4])

                mean_overlapping_bboxes = float(sum(rpn_accuracy_for_epoch)) / len(rpn_accuracy_for_epoch)
                rpn_accuracy_for_epoch = []

                if C.verbose:
                    print('Mean number of bounding boxes from RPN overlapping ground truth boxes: {}'.format(mean_overlapping_bboxes))
                    print('Classifier accuracy for bounding boxes from RPN: {}'.format(class_acc))
                    print('Loss RPN classifier: {}'.format(loss_rpn_cls))
                    print('Loss RPN regression: {}'.format(loss_rpn_regr))
                    print('Loss Detector classifier: {}'.format(loss_class_cls))
                    print('Loss Detector regression: {}'.format(loss_class_regr))
                    print('Total loss: {}'.format(loss_rpn_cls + loss_rpn_regr + loss_class_cls + loss_class_regr))
                    print('Elapsed time: {}'.format(time.time() - start_time))
                    elapsed_time = (time.time()-start_time)/60

                curr_loss = loss_rpn_cls + loss_rpn_regr + loss_class_cls + loss_class_regr
                iter_num = 0
                start_time = time.time()

                if curr_loss < best_loss:
                    if C.verbose:
                        print('Total loss decreased from {} to {}, saving weights'.format(best_loss,curr_loss))
                    best_loss = curr_loss
                    model_all.save_weights(C.model_path)

                new_row = {'mean_overlapping_bboxes':round(mean_overlapping_bboxes, 3), 
                           'class_acc':round(class_acc, 3), 
                           'loss_rpn_cls':round(loss_rpn_cls, 3), 
                           'loss_rpn_regr':round(loss_rpn_regr, 3), 
                           'loss_class_cls':round(loss_class_cls, 3), 
                           'loss_class_regr':round(loss_class_regr, 3), 
                           'curr_loss':round(curr_loss, 3), 
                           'elapsed_time':round(elapsed_time, 3), 
                           'mAP': 0}

                record_df = record_df.append(new_row, ignore_index=True)
                record_df.to_csv(record_path, index=0)

                break

        except Exception as e:
            print('Exception: {}'.format(e))
            continue

print('Training complete, exiting.')
# Out:
# Epoch 1/50
#  24/250 [=>............................] - ETA: 9:33 - rpn_cls: 6.2738 - rpn_regr: 0.1733 - final_cls: 1.3163 - final_regr: 0.3969not enough values to unpack (expected 3, got 2)
# 105/250 [===========>..................] - ETA: 5:21 - rpn_cls: 6.4582 - rpn_regr: 0.2769 - final_cls: 1.1596 - final_regr: 0.3803axes don't match array
# 110/250 [============>.................] - ETA: 5:12 - rpn_cls: 6.4405 - rpn_regr: 0.2807 - final_cls: 1.1550 - final_regr: 0.3794not enough values to unpack (expected 3, got 2)
# 175/250 [====================>.........] - ETA: 2:38 - rpn_cls: 6.2306 - rpn_regr: 0.3311 - final_cls: 1.1065 - final_regr: 0.3654axes don't match array
# 236/250 [===========================>..] - ETA: 29s - rpn_cls: 6.1316 - rpn_regr: 0.3614 - final_cls: 1.0762 - final_regr: 0.3582not enough values to unpack (expected 3, got 2)
# 250/250 [==============================] - 521s 2s/step - rpn_cls: 6.1161 - rpn_regr: 0.3660 - final_cls: 1.0709 - final_regr: 0.3568
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.3969849246231156
# Classifier accuracy for bounding boxes from RPN: 0.668
# Loss RPN classifier: 5.858360156162613
# Loss RPN regression: 0.44220084930956366
# Loss Detector classifier: 0.9825016192793846
# Loss Detector regression: 0.33348862200789153
# Total loss: 7.616551246759452
# Elapsed time: 521.2233772277832
# Total loss decreased from inf to 7.616551246759452, saving weights
# Epoch 2/50
# axes don't match array
#  25/250 [==>...........................] - ETA: 7:33 - rpn_cls: 7.0557 - rpn_regr: 0.2973 - final_cls: 0.9559 - final_regr: 0.4179not enough values to unpack (expected 3, got 2)
#  31/250 [==>...........................] - ETA: 7:15 - rpn_cls: 6.7639 - rpn_regr: 0.3077 - final_cls: 0.9521 - final_regr: 0.3956axes don't match array
#  81/250 [========>.....................] - ETA: 5:33 - rpn_cls: 5.9136 - rpn_regr: 0.3466 - final_cls: 0.9699 - final_regr: 0.3550axes don't match array
# 159/250 [==================>...........] - ETA: 2:44 - rpn_cls: 5.6238 - rpn_regr: 0.3751 - final_cls: 0.9597 - final_regr: 0.3353not enough values to unpack (expected 3, got 2)
# 208/250 [=======================>......] - ETA: 1:16 - rpn_cls: 5.5574 - rpn_regr: 0.3877 - final_cls: 0.9481 - final_regr: 0.3279axes don't match array
# 250/250 [==============================] - 443s 2s/step - rpn_cls: 5.5385 - rpn_regr: 0.3954 - final_cls: 0.9367 - final_regr: 0.3227
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.4280230326295587
# Classifier accuracy for bounding boxes from RPN: 0.715
# Loss RPN classifier: 5.499075162602075
# Loss RPN regression: 0.43320401188731195
# Loss Detector classifier: 0.8580564968883991
# Loss Detector regression: 0.2897471560779959
# Total loss: 7.080082827455783
# Elapsed time: 448.55844235420227
# Total loss decreased from 7.616551246759452 to 7.080082827455783, saving weights
# Epoch 3/50
#  26/250 [==>...........................] - ETA: 6:33 - rpn_cls: 5.4973 - rpn_regr: 0.4166 - final_cls: 0.8035 - final_regr: 0.2520not enough values to unpack (expected 3, got 2)
#  83/250 [========>.....................] - ETA: 4:46 - rpn_cls: 5.9385 - rpn_regr: 0.4448 - final_cls: 0.7707 - final_regr: 0.2642axes don't match array
# not enough values to unpack (expected 3, got 2)
# 128/250 [==============>...............] - ETA: 3:36 - rpn_cls: 5.9786 - rpn_regr: 0.4450 - final_cls: 0.7744 - final_regr: 0.2631not enough values to unpack (expected 3, got 2)
# 191/250 [=====================>........] - ETA: 1:49 - rpn_cls: 5.9697 - rpn_regr: 0.4531 - final_cls: 0.7839 - final_regr: 0.2638axes don't match array
# 250/250 [==============================] - 448s 2s/step - rpn_cls: 5.9504 - rpn_regr: 0.4607 - final_cls: 0.7960 - final_regr: 0.2686
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 1.7079303675048356
# Classifier accuracy for bounding boxes from RPN: 0.725
# Loss RPN classifier: 5.898000103895255
# Loss RPN regression: 0.4755196317769587
# Loss Detector classifier: 0.8520719988346099
# Loss Detector regression: 0.29457284218631685
# Total loss: 7.520164576693141
# Elapsed time: 450.70866894721985
# Epoch 4/50
#  52/250 [=====>........................] - ETA: 6:14 - rpn_cls: 6.3220 - rpn_regr: 0.4033 - final_cls: 1.0418 - final_regr: 0.3855not enough values to unpack (expected 3, got 2)
# 175/250 [====================>.........] - ETA: 2:14 - rpn_cls: 5.8514 - rpn_regr: 0.4070 - final_cls: 0.9418 - final_regr: 0.3274axes don't match array
# 188/250 [=====================>........] - ETA: 1:53 - rpn_cls: 5.8167 - rpn_regr: 0.4070 - final_cls: 0.9352 - final_regr: 0.3239not enough values to unpack (expected 3, got 2)
# 190/250 [=====================>........] - ETA: 1:49 - rpn_cls: 5.8109 - rpn_regr: 0.4071 - final_cls: 0.9343 - final_regr: 0.3234axes don't match array
# 212/250 [========================>.....] - ETA: 1:09 - rpn_cls: 5.7504 - rpn_regr: 0.4075 - final_cls: 0.9245 - final_regr: 0.3180axes don't match array
# 250/250 [==============================] - 464s 2s/step - rpn_cls: 5.6714 - rpn_regr: 0.4083 - final_cls: 0.9093 - final_regr: 0.3097
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 1.9201451905626135
# Classifier accuracy for bounding boxes from RPN: 0.733
# Loss RPN classifier: 5.250066433375212
# Loss RPN regression: 0.4077777964472771
# Loss Detector classifier: 0.8265788940787315
# Loss Detector regression: 0.262316505767405
# Total loss: 6.7467396296686255
# Elapsed time: 463.74124455451965
# Total loss decreased from 7.080082827455783 to 6.7467396296686255, saving weights
# Epoch 5/50
#   5/250 [..............................] - ETA: 5:49 - rpn_cls: 1.1546 - rpn_regr: 0.2339 - final_cls: 1.1953 - final_regr: 0.2370axes don't match array
#   9/250 [>.............................] - ETA: 5:21 - rpn_cls: 2.0862 - rpn_regr: 0.2959 - final_cls: 0.9932 - final_regr: 0.2156axes don't match array
# axes don't match array
#  11/250 [>.............................] - ETA: 6:58 - rpn_cls: 2.6130 - rpn_regr: 0.3000 - final_cls: 0.9327 - final_regr: 0.2027not enough values to unpack (expected 3, got 2)
#  14/250 [>.............................] - ETA: 7:17 - rpn_cls: 3.1651 - rpn_regr: 0.3007 - final_cls: 0.8916 - final_regr: 0.2027not enough values to unpack (expected 3, got 2)
# 116/250 [============>.................] - ETA: 4:14 - rpn_cls: 5.0856 - rpn_regr: 0.3864 - final_cls: 0.9275 - final_regr: 0.2836axes don't match array
# 121/250 [=============>................] - ETA: 4:03 - rpn_cls: 5.0978 - rpn_regr: 0.3881 - final_cls: 0.9299 - final_regr: 0.2855not enough values to unpack (expected 3, got 2)
# 136/250 [===============>..............] - ETA: 3:32 - rpn_cls: 5.1309 - rpn_regr: 0.3926 - final_cls: 0.9360 - final_regr: 0.2910not enough values to unpack (expected 3, got 2)
# 137/250 [===============>..............] - ETA: 3:31 - rpn_cls: 5.1329 - rpn_regr: 0.3929 - final_cls: 0.9363 - final_regr: 0.2913not enough values to unpack (expected 3, got 2)
# 188/250 [=====================>........] - ETA: 1:55 - rpn_cls: 5.1831 - rpn_regr: 0.4014 - final_cls: 0.9440 - final_regr: 0.2999not enough values to unpack (expected 3, got 2)
# 208/250 [=======================>......] - ETA: 1:16 - rpn_cls: 5.1958 - rpn_regr: 0.4034 - final_cls: 0.9458 - final_regr: 0.3023not enough values to unpack (expected 3, got 2)
# 212/250 [========================>.....] - ETA: 1:10 - rpn_cls: 5.1980 - rpn_regr: 0.4038 - final_cls: 0.9460 - final_regr: 0.3027axes don't match array
# 232/250 [==========================>...] - ETA: 33s - rpn_cls: 5.2076 - rpn_regr: 0.4055 - final_cls: 0.9473 - final_regr: 0.3042not enough values to unpack (expected 3, got 2)
# 250/250 [==============================] - 470s 2s/step - rpn_cls: 5.2164 - rpn_regr: 0.4067 - final_cls: 0.9487 - final_regr: 0.3056
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.8886861313868613
# Classifier accuracy for bounding boxes from RPN: 0.656
# Loss RPN classifier: 5.33013839940198
# Loss RPN regression: 0.41501117940992116
# Loss Detector classifier: 0.965372641146183
# Loss Detector regression: 0.3221862536072731
# Total loss: 7.032708473565357
# Elapsed time: 472.7841832637787
# Epoch 6/50
#   8/250 [..............................] - ETA: 9:52 - rpn_cls: 6.2350 - rpn_regr: 0.6842 - final_cls: 0.8969 - final_regr: 0.2045axes don't match array
#  14/250 [>.............................] - ETA: 10:00 - rpn_cls: 6.2705 - rpn_regr: 0.5859 - final_cls: 0.9052 - final_regr: 0.2406axes don't match array
#  47/250 [====>.........................] - ETA: 7:24 - rpn_cls: 5.8291 - rpn_regr: 0.4222 - final_cls: 0.9335 - final_regr: 0.3388axes don't match array
# 214/250 [========================>.....] - ETA: 1:08 - rpn_cls: 5.7259 - rpn_regr: 0.4180 - final_cls: 0.9362 - final_regr: 0.3285axes don't match array
# 241/250 [===========================>..] - ETA: 17s - rpn_cls: 5.7257 - rpn_regr: 0.4188 - final_cls: 0.9329 - final_regr: 0.3249not enough values to unpack (expected 3, got 2)
# 243/250 [============================>.] - ETA: 13s - rpn_cls: 5.7254 - rpn_regr: 0.4188 - final_cls: 0.9326 - final_regr: 0.3247axes don't match array
# 244/250 [============================>.] - ETA: 11s - rpn_cls: 5.7252 - rpn_regr: 0.4189 - final_cls: 0.9325 - final_regr: 0.3245axes don't match array
# 250/250 [==============================] - 494s 2s/step - rpn_cls: 5.7235 - rpn_regr: 0.4191 - final_cls: 0.9319 - final_regr: 0.3238
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.0757575757575757
# Classifier accuracy for bounding boxes from RPN: 0.677
# Loss RPN classifier: 5.632851897266279
# Loss RPN regression: 0.42736539207398894
# Loss Detector classifier: 0.9100522069931031
# Loss Detector regression: 0.2984230109862983
# Total loss: 7.2686925073196695
# Elapsed time: 493.96096324920654
# Epoch 7/50
#  18/250 [=>............................] - ETA: 7:37 - rpn_cls: 8.0131 - rpn_regr: 0.5000 - final_cls: 0.9549 - final_regr: 0.2834axes don't match array
#  51/250 [=====>........................] - ETA: 6:08 - rpn_cls: 6.8711 - rpn_regr: 0.4907 - final_cls: 0.8970 - final_regr: 0.2987not enough values to unpack (expected 3, got 2)
# axes don't match array
#  81/250 [========>.....................] - ETA: 5:21 - rpn_cls: 6.5147 - rpn_regr: 0.4846 - final_cls: 0.8839 - final_regr: 0.2919not enough values to unpack (expected 3, got 2)
# 169/250 [===================>..........] - ETA: 2:32 - rpn_cls: 6.3926 - rpn_regr: 0.4715 - final_cls: 0.8746 - final_regr: 0.2928not enough values to unpack (expected 3, got 2)
# 174/250 [===================>..........] - ETA: 2:24 - rpn_cls: 6.3844 - rpn_regr: 0.4715 - final_cls: 0.8746 - final_regr: 0.2929not enough values to unpack (expected 3, got 2)
# 239/250 [===========================>..] - ETA: 20s - rpn_cls: 6.2988 - rpn_regr: 0.4771 - final_cls: 0.8756 - final_regr: 0.2917not enough values to unpack (expected 3, got 2)
# 250/250 [==============================] - 476s 2s/step - rpn_cls: 6.2845 - rpn_regr: 0.4785 - final_cls: 0.8760 - final_regr: 0.2913
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.0678260869565217
# Classifier accuracy for bounding boxes from RPN: 0.71
# Loss RPN classifier: 5.9581708206849875
# Loss RPN regression: 0.5113810947984457
# Loss Detector classifier: 0.8911983346045017
# Loss Detector regression: 0.28533748134505005
# Total loss: 7.646087731432985
# Elapsed time: 476.1765863895416
# Epoch 8/50
#  48/250 [====>.........................] - ETA: 6:55 - rpn_cls: 4.8459 - rpn_regr: 0.3889 - final_cls: 0.7462 - final_regr: 0.2133axes don't match array
#  62/250 [======>.......................] - ETA: 6:16 - rpn_cls: 5.0189 - rpn_regr: 0.3921 - final_cls: 0.7778 - final_regr: 0.2282axes don't match array
#  88/250 [=========>....................] - ETA: 5:19 - rpn_cls: 5.2023 - rpn_regr: 0.3907 - final_cls: 0.8124 - final_regr: 0.2490not enough values to unpack (expected 3, got 2)
#  94/250 [==========>...................] - ETA: 5:06 - rpn_cls: 5.2355 - rpn_regr: 0.3916 - final_cls: 0.8176 - final_regr: 0.2515axes don't match array
# 143/250 [================>.............] - ETA: 3:30 - rpn_cls: 5.4006 - rpn_regr: 0.3945 - final_cls: 0.8398 - final_regr: 0.2628axes don't match array
# 221/250 [=========================>....] - ETA: 53s - rpn_cls: 5.5015 - rpn_regr: 0.4036 - final_cls: 0.8530 - final_regr: 0.2737axes don't match array
# 250/250 [==============================] - 459s 2s/step - rpn_cls: 5.5274 - rpn_regr: 0.4077 - final_cls: 0.8527 - final_regr: 0.2747
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 1.773308957952468
# Classifier accuracy for bounding boxes from RPN: 0.727
# Loss RPN classifier: 5.745530553951168
# Loss RPN regression: 0.44274085014965386
# Loss Detector classifier: 0.8424345267415047
# Loss Detector regression: 0.27935667409189047
# Total loss: 7.310062604934217
# Elapsed time: 458.99949884414673
# Epoch 9/50
#  20/250 [=>............................] - ETA: 7:40 - rpn_cls: 7.4352 - rpn_regr: 0.6397 - final_cls: 0.5222 - final_regr: 0.1515not enough values to unpack (expected 3, got 2)
#  89/250 [=========>....................] - ETA: 4:28 - rpn_cls: 5.9644 - rpn_regr: 0.4732 - final_cls: 0.6902 - final_regr: 0.2322axes don't match array
# 144/250 [================>.............] - ETA: 2:57 - rpn_cls: 5.9658 - rpn_regr: 0.4610 - final_cls: 0.7223 - final_regr: 0.2433not enough values to unpack (expected 3, got 2)
# not enough values to unpack (expected 3, got 2)
# 189/250 [=====================>........] - ETA: 1:45 - rpn_cls: 5.9619 - rpn_regr: 0.4560 - final_cls: 0.7479 - final_regr: 0.2516axes don't match array
# 250/250 [==============================] - 447s 2s/step - rpn_cls: 5.9559 - rpn_regr: 0.4546 - final_cls: 0.7717 - final_regr: 0.2587
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 1.9546313799621928
# Classifier accuracy for bounding boxes from RPN: 0.717
# Loss RPN classifier: 5.863738495246539
# Loss RPN regression: 0.47090423553436994
# Loss Detector classifier: 0.849618634223938
# Loss Detector regression: 0.28134729272313413
# Total loss: 7.46560865772798
# Elapsed time: 447.4186165332794
# Epoch 10/50
#   1/250 [..............................] - ETA: 3:34 - rpn_cls: 6.7076 - rpn_regr: 0.2681 - final_cls: 1.8116 - final_regr: 0.7894not enough values to unpack (expected 3, got 2)
# 112/250 [============>.................] - ETA: 3:55 - rpn_cls: 5.9673 - rpn_regr: 0.4218 - final_cls: 0.9332 - final_regr: 0.3588axes don't match array
# 239/250 [===========================>..] - ETA: 18s - rpn_cls: 5.9300 - rpn_regr: 0.4293 - final_cls: 0.8890 - final_regr: 0.3164not enough values to unpack (expected 3, got 2)
# 250/250 [==============================] - 422s 2s/step - rpn_cls: 5.9187 - rpn_regr: 0.4299 - final_cls: 0.8871 - final_regr: 0.3148
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.1538461538461537
# Classifier accuracy for bounding boxes from RPN: 0.722
# Loss RPN classifier: 5.629594703194511
# Loss RPN regression: 0.44286930506676436
# Loss Detector classifier: 0.8423606405556202
# Loss Detector regression: 0.2787447616234422
# Total loss: 7.193569410440338
# Elapsed time: 422.4615261554718
# Epoch 11/50
#   3/250 [..............................] - ETA: 12:37 - rpn_cls: 1.9553 - rpn_regr: 1.6089 - final_cls: 0.5760 - final_regr: 0.1703axes don't match array
#   5/250 [..............................] - ETA: 10:42 - rpn_cls: 2.1024 - rpn_regr: 1.3640 - final_cls: 0.8171 - final_regr: 0.2168not enough values to unpack (expected 3, got 2)
#  27/250 [==>...........................] - ETA: 7:19 - rpn_cls: 3.5890 - rpn_regr: 0.6809 - final_cls: 0.8523 - final_regr: 0.2331axes don't match array
#  71/250 [=======>......................] - ETA: 5:45 - rpn_cls: 4.4361 - rpn_regr: 0.5378 - final_cls: 0.8508 - final_regr: 0.2626not enough values to unpack (expected 3, got 2)
#  75/250 [========>.....................] - ETA: 5:31 - rpn_cls: 4.4677 - rpn_regr: 0.5319 - final_cls: 0.8513 - final_regr: 0.2637axes don't match array
# not enough values to unpack (expected 3, got 2)
#  77/250 [========>.....................] - ETA: 5:34 - rpn_cls: 4.4867 - rpn_regr: 0.5289 - final_cls: 0.8515 - final_regr: 0.2643not enough values to unpack (expected 3, got 2)
#  80/250 [========>.....................] - ETA: 5:30 - rpn_cls: 4.5152 - rpn_regr: 0.5245 - final_cls: 0.8519 - final_regr: 0.2652axes don't match array
# 181/250 [====================>.........] - ETA: 2:12 - rpn_cls: 4.9402 - rpn_regr: 0.4626 - final_cls: 0.8840 - final_regr: 0.2861axes don't match array
# 185/250 [=====================>........] - ETA: 2:04 - rpn_cls: 4.9480 - rpn_regr: 0.4618 - final_cls: 0.8854 - final_regr: 0.2870axes don't match array
# 201/250 [=======================>......] - ETA: 1:33 - rpn_cls: 4.9755 - rpn_regr: 0.4593 - final_cls: 0.8903 - final_regr: 0.2904not enough values to unpack (expected 3, got 2)
# 202/250 [=======================>......] - ETA: 1:31 - rpn_cls: 4.9772 - rpn_regr: 0.4592 - final_cls: 0.8905 - final_regr: 0.2906axes don't match array
# 250/250 [==============================] - 473s 2s/step - rpn_cls: 5.0467 - rpn_regr: 0.4532 - final_cls: 0.8984 - final_regr: 0.2976
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.124548736462094
# Classifier accuracy for bounding boxes from RPN: 0.664
# Loss RPN classifier: 5.2429745788087825
# Loss RPN regression: 0.4285336502045393
# Loss Detector classifier: 0.9252620784044265
# Loss Detector regression: 0.32814021870493887
# Total loss: 6.924910526122686
# Elapsed time: 473.44287109375
# Epoch 12/50
#   4/250 [..............................] - ETA: 6:56 - rpn_cls: 5.2249 - rpn_regr: 0.4761 - final_cls: 0.5909 - final_regr: 0.0903axes don't match array
#  24/250 [=>............................] - ETA: 5:55 - rpn_cls: 5.1992 - rpn_regr: 0.4609 - final_cls: 0.7813 - final_regr: 0.2772not enough values to unpack (expected 3, got 2)
#  28/250 [==>...........................] - ETA: 6:17 - rpn_cls: 5.2741 - rpn_regr: 0.4587 - final_cls: 0.7905 - final_regr: 0.2815axes don't match array
#  47/250 [====>.........................] - ETA: 6:28 - rpn_cls: 5.5259 - rpn_regr: 0.4507 - final_cls: 0.8488 - final_regr: 0.2934axes don't match array
#  73/250 [=======>......................] - ETA: 5:50 - rpn_cls: 5.5206 - rpn_regr: 0.4416 - final_cls: 0.8859 - final_regr: 0.3047not enough values to unpack (expected 3, got 2)
#  80/250 [========>.....................] - ETA: 5:41 - rpn_cls: 5.5195 - rpn_regr: 0.4392 - final_cls: 0.8905 - final_regr: 0.3061not enough values to unpack (expected 3, got 2)
# 113/250 [============>.................] - ETA: 4:35 - rpn_cls: 5.4970 - rpn_regr: 0.4306 - final_cls: 0.9037 - final_regr: 0.3111axes don't match array
# 250/250 [==============================] - 474s 2s/step - rpn_cls: 5.4584 - rpn_regr: 0.4250 - final_cls: 0.9204 - final_regr: 0.3129
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.6514886164623466
# Classifier accuracy for bounding boxes from RPN: 0.675
# Loss RPN classifier: 5.467523696273042
# Loss RPN regression: 0.43353834420442583
# Loss Detector classifier: 0.9273507806956768
# Loss Detector regression: 0.314135719537735
# Total loss: 7.14254854071088
# Elapsed time: 474.37245082855225
# Epoch 13/50
#  28/250 [==>...........................] - ETA: 7:14 - rpn_cls: 5.5076 - rpn_regr: 0.3694 - final_cls: 0.8338 - final_regr: 0.3215not enough values to unpack (expected 3, got 2)
#  54/250 [=====>........................] - ETA: 7:10 - rpn_cls: 5.3321 - rpn_regr: 0.3725 - final_cls: 0.8719 - final_regr: 0.3007axes don't match array
#  57/250 [=====>........................] - ETA: 7:01 - rpn_cls: 5.3224 - rpn_regr: 0.3744 - final_cls: 0.8717 - final_regr: 0.2993axes don't match array
#  58/250 [=====>........................] - ETA: 7:05 - rpn_cls: 5.3185 - rpn_regr: 0.3749 - final_cls: 0.8718 - final_regr: 0.2990not enough values to unpack (expected 3, got 2)
#  80/250 [========>.....................] - ETA: 6:21 - rpn_cls: 5.2857 - rpn_regr: 0.3841 - final_cls: 0.8793 - final_regr: 0.2966axes don't match array
# 112/250 [============>.................] - ETA: 4:54 - rpn_cls: 5.2828 - rpn_regr: 0.3946 - final_cls: 0.8809 - final_regr: 0.2965not enough values to unpack (expected 3, got 2)
# not enough values to unpack (expected 3, got 2)
# 141/250 [===============>..............] - ETA: 3:49 - rpn_cls: 5.2776 - rpn_regr: 0.4004 - final_cls: 0.8830 - final_regr: 0.2941axes don't match array
# 227/250 [==========================>...] - ETA: 46s - rpn_cls: 5.3780 - rpn_regr: 0.4106 - final_cls: 0.8785 - final_regr: 0.2904axes don't match array
# 232/250 [==========================>...] - ETA: 36s - rpn_cls: 5.3809 - rpn_regr: 0.4111 - final_cls: 0.8782 - final_regr: 0.2903axes don't match array
# 250/250 [==============================] - 502s 2s/step - rpn_cls: 5.3974 - rpn_regr: 0.4136 - final_cls: 0.8766 - final_regr: 0.2898
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.2557755775577557
# Classifier accuracy for bounding boxes from RPN: 0.701
# Loss RPN classifier: 5.641655476584582
# Loss RPN regression: 0.44958775594085454
# Loss Detector classifier: 0.8525308848619461
# Loss Detector regression: 0.28333541975915433
# Total loss: 7.227109537146537
# Elapsed time: 502.1081359386444
# Epoch 14/50
#  48/250 [====>.........................] - ETA: 6:30 - rpn_cls: 4.8978 - rpn_regr: 0.4800 - final_cls: 0.9423 - final_regr: 0.3402not enough values to unpack (expected 3, got 2)
# 109/250 [============>.................] - ETA: 4:34 - rpn_cls: 4.9521 - rpn_regr: 0.5201 - final_cls: 0.9067 - final_regr: 0.3227not enough values to unpack (expected 3, got 2)
# 122/250 [=============>................] - ETA: 4:08 - rpn_cls: 4.9748 - rpn_regr: 0.5192 - final_cls: 0.9060 - final_regr: 0.3217axes don't match array
# 149/250 [================>.............] - ETA: 3:13 - rpn_cls: 5.0033 - rpn_regr: 0.5162 - final_cls: 0.9059 - final_regr: 0.3208axes don't match array
# 155/250 [=================>............] - ETA: 3:02 - rpn_cls: 5.0130 - rpn_regr: 0.5158 - final_cls: 0.9061 - final_regr: 0.3203not enough values to unpack (expected 3, got 2)
# 205/250 [=======================>......] - ETA: 1:25 - rpn_cls: 5.0860 - rpn_regr: 0.5096 - final_cls: 0.9054 - final_regr: 0.3163axes don't match array
# 250/250 [==============================] - 468s 2s/step - rpn_cls: 5.1189 - rpn_regr: 0.5040 - final_cls: 0.9041 - final_regr: 0.3124
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.5247349823321557
# Classifier accuracy for bounding boxes from RPN: 0.698
# Loss RPN classifier: 5.282201003601155
# Loss RPN regression: 0.4854654804766178
# Loss Detector classifier: 0.8852222373783588
# Loss Detector regression: 0.29245135283470153
# Total loss: 6.945340074290833
# Elapsed time: 467.6805417537689
# Epoch 15/50
#  35/250 [===>..........................] - ETA: 4:59 - rpn_cls: 4.4504 - rpn_regr: 0.5407 - final_cls: 0.8214 - final_regr: 0.3332axes don't match array
#  84/250 [=========>....................] - ETA: 4:34 - rpn_cls: 5.1350 - rpn_regr: 0.5079 - final_cls: 0.8607 - final_regr: 0.3121not enough values to unpack (expected 3, got 2)
# 149/250 [================>.............] - ETA: 2:44 - rpn_cls: 5.5269 - rpn_regr: 0.4812 - final_cls: 0.8798 - final_regr: 0.3139not enough values to unpack (expected 3, got 2)
# 204/250 [=======================>......] - ETA: 1:15 - rpn_cls: 5.6654 - rpn_regr: 0.4698 - final_cls: 0.8869 - final_regr: 0.3163axes don't match array
# not enough values to unpack (expected 3, got 2)
# 247/250 [============================>.] - ETA: 5s - rpn_cls: 5.7054 - rpn_regr: 0.4639 - final_cls: 0.8917 - final_regr: 0.3179axes don't match array
# 250/250 [==============================] - 422s 2s/step - rpn_cls: 5.7074 - rpn_regr: 0.4636 - final_cls: 0.8920 - final_regr: 0.3180
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.4196078431372547
# Classifier accuracy for bounding boxes from RPN: 0.663
# Loss RPN classifier: 5.885863529384678
# Loss RPN regression: 0.43871627205610275
# Loss Detector classifier: 0.9162823413312435
# Loss Detector regression: 0.32530626833438875
# Total loss: 7.566168411106412
# Elapsed time: 421.63348031044006
# Epoch 16/50
#  60/250 [======>.......................] - ETA: 6:02 - rpn_cls: 5.6793 - rpn_regr: 0.5283 - final_cls: 0.9592 - final_regr: 0.2939not enough values to unpack (expected 3, got 2)
# 174/250 [===================>..........] - ETA: 2:11 - rpn_cls: 5.6214 - rpn_regr: 0.5206 - final_cls: 0.9281 - final_regr: 0.2889axes don't match array
# 250/250 [==============================] - 432s 2s/step - rpn_cls: 5.6513 - rpn_regr: 0.5054 - final_cls: 0.9173 - final_regr: 0.2888
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.8745247148288975
# Classifier accuracy for bounding boxes from RPN: 0.696
# Loss RPN classifier: 5.798141924916845
# Loss RPN regression: 0.46272803923115136
# Loss Detector classifier: 0.8951259131431579
# Loss Detector regression: 0.28862128416262567
# Total loss: 7.444617161453779
# Elapsed time: 432.26970744132996
# Epoch 17/50
#  47/250 [====>.........................] - ETA: 5:44 - rpn_cls: 4.4075 - rpn_regr: 0.4207 - final_cls: 0.9723 - final_regr: 0.2856axes don't match array
#  60/250 [======>.......................] - ETA: 5:45 - rpn_cls: 4.5393 - rpn_regr: 0.4192 - final_cls: 0.9661 - final_regr: 0.2893not enough values to unpack (expected 3, got 2)
#  61/250 [======>.......................] - ETA: 5:43 - rpn_cls: 4.5455 - rpn_regr: 0.4194 - final_cls: 0.9664 - final_regr: 0.2897not enough values to unpack (expected 3, got 2)
#  83/250 [========>.....................] - ETA: 5:03 - rpn_cls: 4.6912 - rpn_regr: 0.4168 - final_cls: 0.9625 - final_regr: 0.2942axes don't match array
# 125/250 [==============>...............] - ETA: 3:52 - rpn_cls: 4.8373 - rpn_regr: 0.4155 - final_cls: 0.9502 - final_regr: 0.2940axes don't match array
# 129/250 [==============>...............] - ETA: 3:42 - rpn_cls: 4.8487 - rpn_regr: 0.4151 - final_cls: 0.9494 - final_regr: 0.2938axes don't match array
# axes don't match array
# 131/250 [==============>...............] - ETA: 3:41 - rpn_cls: 4.8561 - rpn_regr: 0.4148 - final_cls: 0.9489 - final_regr: 0.2937not enough values to unpack (expected 3, got 2)
# 134/250 [===============>..............] - ETA: 3:36 - rpn_cls: 4.8677 - rpn_regr: 0.4143 - final_cls: 0.9483 - final_regr: 0.2937axes don't match array
# 237/250 [===========================>..] - ETA: 24s - rpn_cls: 5.1380 - rpn_regr: 0.4142 - final_cls: 0.9373 - final_regr: 0.2942axes don't match array
# 242/250 [============================>.] - ETA: 14s - rpn_cls: 5.1445 - rpn_regr: 0.4144 - final_cls: 0.9374 - final_regr: 0.2944axes don't match array
# 250/250 [==============================] - 462s 2s/step - rpn_cls: 5.1547 - rpn_regr: 0.4148 - final_cls: 0.9375 - final_regr: 0.2947
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.276481149012567
# Classifier accuracy for bounding boxes from RPN: 0.654
# Loss RPN classifier: 5.440370460642036
# Loss RPN regression: 0.42835460798814895
# Loss Detector classifier: 0.9392661570906639
# Loss Detector regression: 0.3064351053610444
# Total loss: 7.114426331081894
# Elapsed time: 461.91578936576843
# Epoch 18/50
#   7/250 [..............................] - ETA: 5:38 - rpn_cls: 4.4789 - rpn_regr: 0.2413 - final_cls: 0.8420 - final_regr: 0.3259axes don't match array
#   8/250 [..............................] - ETA: 6:30 - rpn_cls: 4.6989 - rpn_regr: 0.2620 - final_cls: 0.8486 - final_regr: 0.3285axes don't match array
#  58/250 [=====>........................] - ETA: 5:46 - rpn_cls: 5.5854 - rpn_regr: 0.3673 - final_cls: 0.8673 - final_regr: 0.2982not enough values to unpack (expected 3, got 2)
#  78/250 [========>.....................] - ETA: 4:58 - rpn_cls: 5.6047 - rpn_regr: 0.3773 - final_cls: 0.8709 - final_regr: 0.3038axes don't match array
#  83/250 [========>.....................] - ETA: 4:51 - rpn_cls: 5.6009 - rpn_regr: 0.3792 - final_cls: 0.8713 - final_regr: 0.3053not enough values to unpack (expected 3, got 2)
# 104/250 [===========>..................] - ETA: 4:23 - rpn_cls: 5.5476 - rpn_regr: 0.3853 - final_cls: 0.8785 - final_regr: 0.3126not enough values to unpack (expected 3, got 2)
# 133/250 [==============>...............] - ETA: 3:31 - rpn_cls: 5.4913 - rpn_regr: 0.3911 - final_cls: 0.8847 - final_regr: 0.3191not enough values to unpack (expected 3, got 2)
# 140/250 [===============>..............] - ETA: 3:21 - rpn_cls: 5.4854 - rpn_regr: 0.3936 - final_cls: 0.8845 - final_regr: 0.3193axes don't match array
# 173/250 [===================>..........] - ETA: 2:23 - rpn_cls: 5.4639 - rpn_regr: 0.4008 - final_cls: 0.8850 - final_regr: 0.3202axes don't match array
# 250/250 [==============================] - 455s 2s/step - rpn_cls: 5.4502 - rpn_regr: 0.4113 - final_cls: 0.8846 - final_regr: 0.3195
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.335144927536232
# Classifier accuracy for bounding boxes from RPN: 0.68
# Loss RPN classifier: 5.431598564543976
# Loss RPN regression: 0.44582146514207127
# Loss Detector classifier: 0.8960071256514639
# Loss Detector regression: 0.32259293097257613
# Total loss: 7.096020086310087
# Elapsed time: 454.5644836425781
# Epoch 19/50
#  94/250 [==========>...................] - ETA: 4:34 - rpn_cls: 5.6448 - rpn_regr: 0.4418 - final_cls: 0.8266 - final_regr: 0.3162axes don't match array
# 121/250 [=============>................] - ETA: 4:02 - rpn_cls: 5.5416 - rpn_regr: 0.4404 - final_cls: 0.8329 - final_regr: 0.3112not enough values to unpack (expected 3, got 2)
# 124/250 [=============>................] - ETA: 3:57 - rpn_cls: 5.5310 - rpn_regr: 0.4406 - final_cls: 0.8332 - final_regr: 0.3107axes don't match array
# 125/250 [==============>...............] - ETA: 3:57 - rpn_cls: 5.5276 - rpn_regr: 0.4406 - final_cls: 0.8333 - final_regr: 0.3105axes don't match array
# 150/250 [=================>............] - ETA: 3:11 - rpn_cls: 5.4479 - rpn_regr: 0.4413 - final_cls: 0.8375 - final_regr: 0.3074not enough values to unpack (expected 3, got 2)
# 182/250 [====================>.........] - ETA: 2:08 - rpn_cls: 5.3906 - rpn_regr: 0.4424 - final_cls: 0.8410 - final_regr: 0.3054not enough values to unpack (expected 3, got 2)
# not enough values to unpack (expected 3, got 2)
# 213/250 [========================>.....] - ETA: 1:09 - rpn_cls: 5.3471 - rpn_regr: 0.4429 - final_cls: 0.8434 - final_regr: 0.3045axes don't match array
# 250/250 [==============================] - 470s 2s/step - rpn_cls: 5.3389 - rpn_regr: 0.4420 - final_cls: 0.8465 - final_regr: 0.3043
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.592400690846287
# Classifier accuracy for bounding boxes from RPN: 0.697
# Loss RPN classifier: 5.330771370317908
# Loss RPN regression: 0.4397819110415876
# Loss Detector classifier: 0.861688726618886
# Loss Detector regression: 0.3042318892478943
# Total loss: 6.936473897226277
# Elapsed time: 470.33551502227783
# Epoch 20/50
#  48/250 [====>.........................] - ETA: 6:36 - rpn_cls: 6.8674 - rpn_regr: 0.4997 - final_cls: 1.0326 - final_regr: 0.3688not enough values to unpack (expected 3, got 2)
#  53/250 [=====>........................] - ETA: 6:36 - rpn_cls: 6.7728 - rpn_regr: 0.4985 - final_cls: 1.0297 - final_regr: 0.3679axes don't match array
# 120/250 [=============>................] - ETA: 4:03 - rpn_cls: 6.1678 - rpn_regr: 0.5256 - final_cls: 0.9638 - final_regr: 0.3428axes don't match array
# 180/250 [====================>.........] - ETA: 2:13 - rpn_cls: 5.9648 - rpn_regr: 0.5303 - final_cls: 0.9437 - final_regr: 0.3296axes don't match array
# 194/250 [======================>.......] - ETA: 1:46 - rpn_cls: 5.9334 - rpn_regr: 0.5295 - final_cls: 0.9413 - final_regr: 0.3275not enough values to unpack (expected 3, got 2)
# 220/250 [=========================>....] - ETA: 56s - rpn_cls: 5.8897 - rpn_regr: 0.5270 - final_cls: 0.9381 - final_regr: 0.3256axes don't match array
# 226/250 [==========================>...] - ETA: 45s - rpn_cls: 5.8813 - rpn_regr: 0.5264 - final_cls: 0.9375 - final_regr: 0.3252not enough values to unpack (expected 3, got 2)
# 250/250 [==============================] - 472s 2s/step - rpn_cls: 5.8511 - rpn_regr: 0.5234 - final_cls: 0.9355 - final_regr: 0.3238
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.884083044982699
# Classifier accuracy for bounding boxes from RPN: 0.684
# Loss RPN classifier: 5.558929478729558
# Loss RPN regression: 0.4951839748471975
# Loss Detector classifier: 0.9074780323505401
# Loss Detector regression: 0.3080421080701053
# Total loss: 7.269633593997401
# Elapsed time: 472.00896739959717
# Epoch 21/50
#  25/250 [==>...........................] - ETA: 7:15 - rpn_cls: 5.0168 - rpn_regr: 0.6320 - final_cls: 0.9118 - final_regr: 0.2631not enough values to unpack (expected 3, got 2)
# 104/250 [===========>..................] - ETA: 3:58 - rpn_cls: 5.0656 - rpn_regr: 0.4989 - final_cls: 0.9331 - final_regr: 0.2925not enough values to unpack (expected 3, got 2)
# 151/250 [=================>............] - ETA: 2:49 - rpn_cls: 5.0685 - rpn_regr: 0.4896 - final_cls: 0.9282 - final_regr: 0.2928axes don't match array
# 219/250 [=========================>....] - ETA: 51s - rpn_cls: 5.1642 - rpn_regr: 0.4752 - final_cls: 0.9175 - final_regr: 0.2938axes don't match array
# 250/250 [==============================] - 412s 2s/step - rpn_cls: 5.2089 - rpn_regr: 0.4710 - final_cls: 0.9130 - final_regr: 0.2951
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.52465483234714
# Classifier accuracy for bounding boxes from RPN: 0.686
# Loss RPN classifier: 5.542876853592315
# Loss RPN regression: 0.4530843124091625
# Loss Detector classifier: 0.8884176824688912
# Loss Detector regression: 0.30911544418334963
# Total loss: 7.1934942926537175
# Elapsed time: 412.5062851905823
# Epoch 22/50
#  25/250 [==>...........................] - ETA: 6:05 - rpn_cls: 4.7067 - rpn_regr: 0.3384 - final_cls: 0.9247 - final_regr: 0.3832axes don't match array
# not enough values to unpack (expected 3, got 2)
#  68/250 [=======>......................] - ETA: 5:27 - rpn_cls: 5.1770 - rpn_regr: 0.3632 - final_cls: 0.9488 - final_regr: 0.3592axes don't match array
# 130/250 [==============>...............] - ETA: 3:43 - rpn_cls: 5.3037 - rpn_regr: 0.4040 - final_cls: 0.9445 - final_regr: 0.3525not enough values to unpack (expected 3, got 2)
# 244/250 [============================>.] - ETA: 10s - rpn_cls: 5.4758 - rpn_regr: 0.4358 - final_cls: 0.9353 - final_regr: 0.3448axes don't match array
# 250/250 [==============================] - 442s 2s/step - rpn_cls: 5.4831 - rpn_regr: 0.4364 - final_cls: 0.9347 - final_regr: 0.3443
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.3104089219330857
# Classifier accuracy for bounding boxes from RPN: 0.675
# Loss RPN classifier: 5.761747722671556
# Loss RPN regression: 0.4617982636354864
# Loss Detector classifier: 0.906945319712162
# Loss Detector regression: 0.3224891231898218
# Total loss: 7.452980429209027
# Elapsed time: 441.6346218585968
# Epoch 23/50
# 119/250 [=============>................] - ETA: 3:34 - rpn_cls: 5.4473 - rpn_regr: 0.4571 - final_cls: 0.9302 - final_regr: 0.3052not enough values to unpack (expected 3, got 2)
# 134/250 [===============>..............] - ETA: 3:13 - rpn_cls: 5.3819 - rpn_regr: 0.4572 - final_cls: 0.9292 - final_regr: 0.3072not enough values to unpack (expected 3, got 2)
# 136/250 [===============>..............] - ETA: 3:09 - rpn_cls: 5.3737 - rpn_regr: 0.4575 - final_cls: 0.9292 - final_regr: 0.3074not enough values to unpack (expected 3, got 2)
# 158/250 [=================>............] - ETA: 2:34 - rpn_cls: 5.3158 - rpn_regr: 0.4576 - final_cls: 0.9273 - final_regr: 0.3083axes don't match array
# 203/250 [=======================>......] - ETA: 1:20 - rpn_cls: 5.2477 - rpn_regr: 0.4585 - final_cls: 0.9206 - final_regr: 0.3080axes don't match array
# 207/250 [=======================>......] - ETA: 1:12 - rpn_cls: 5.2452 - rpn_regr: 0.4585 - final_cls: 0.9199 - final_regr: 0.3079not enough values to unpack (expected 3, got 2)
# axes don't match array
# 209/250 [========================>.....] - ETA: 1:10 - rpn_cls: 5.2445 - rpn_regr: 0.4585 - final_cls: 0.9196 - final_regr: 0.3079axes don't match array
# 212/250 [========================>.....] - ETA: 1:05 - rpn_cls: 5.2432 - rpn_regr: 0.4585 - final_cls: 0.9191 - final_regr: 0.3079not enough values to unpack (expected 3, got 2)
# 250/250 [==============================] - 437s 2s/step - rpn_cls: 5.2195 - rpn_regr: 0.4574 - final_cls: 0.9144 - final_regr: 0.3077
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.6772983114446527
# Classifier accuracy for bounding boxes from RPN: 0.688
# Loss RPN classifier: 4.997329119472186
# Loss RPN regression: 0.4587616606652737
# Loss Detector classifier: 0.8807997899204493
# Loss Detector regression: 0.29944342958927156
# Total loss: 6.636333999647181
# Elapsed time: 436.8399770259857
# Total loss decreased from 6.7467396296686255 to 6.636333999647181, saving weights
# Epoch 24/50
#  63/250 [======>.......................] - ETA: 5:42 - rpn_cls: 4.5670 - rpn_regr: 0.4050 - final_cls: 1.0610 - final_regr: 0.3381not enough values to unpack (expected 3, got 2)
#  68/250 [=======>......................] - ETA: 5:30 - rpn_cls: 4.5870 - rpn_regr: 0.4079 - final_cls: 1.0601 - final_regr: 0.3382not enough values to unpack (expected 3, got 2)
#  84/250 [=========>....................] - ETA: 4:54 - rpn_cls: 4.6417 - rpn_regr: 0.4162 - final_cls: 1.0516 - final_regr: 0.3373axes don't match array
#  85/250 [=========>....................] - ETA: 4:55 - rpn_cls: 4.6452 - rpn_regr: 0.4167 - final_cls: 1.0510 - final_regr: 0.3372axes don't match array
# 137/250 [===============>..............] - ETA: 3:21 - rpn_cls: 4.8212 - rpn_regr: 0.4268 - final_cls: 1.0125 - final_regr: 0.3275not enough values to unpack (expected 3, got 2)
# 157/250 [=================>............] - ETA: 2:42 - rpn_cls: 4.8498 - rpn_regr: 0.4276 - final_cls: 1.0019 - final_regr: 0.3259axes don't match array
# 162/250 [==================>...........] - ETA: 2:34 - rpn_cls: 4.8580 - rpn_regr: 0.4279 - final_cls: 0.9997 - final_regr: 0.3256axes don't match array
# 184/250 [=====================>........] - ETA: 1:57 - rpn_cls: 4.8911 - rpn_regr: 0.4287 - final_cls: 0.9917 - final_regr: 0.3245not enough values to unpack (expected 3, got 2)
# 211/250 [========================>.....] - ETA: 1:10 - rpn_cls: 4.9223 - rpn_regr: 0.4283 - final_cls: 0.9841 - final_regr: 0.3239not enough values to unpack (expected 3, got 2)
# 217/250 [=========================>....] - ETA: 1:00 - rpn_cls: 4.9296 - rpn_regr: 0.4282 - final_cls: 0.9826 - final_regr: 0.3239not enough values to unpack (expected 3, got 2)
# 250/250 [==============================] - 461s 2s/step - rpn_cls: 4.9666 - rpn_regr: 0.4263 - final_cls: 0.9759 - final_regr: 0.3235
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.07871198568873
# Classifier accuracy for bounding boxes from RPN: 0.656
# Loss RPN classifier: 5.249626813596589
# Loss RPN regression: 0.4124490283951163
# Loss Detector classifier: 0.9339495563432574
# Loss Detector regression: 0.31595084303617477
# Total loss: 6.911976241371137
# Elapsed time: 463.54008960723877
# Epoch 25/50
# axes don't match array
# 167/250 [===================>..........] - ETA: 2:27 - rpn_cls: 5.4364 - rpn_regr: 0.4261 - final_cls: 0.8962 - final_regr: 0.2705axes don't match array
# 193/250 [======================>.......] - ETA: 1:46 - rpn_cls: 5.4563 - rpn_regr: 0.4265 - final_cls: 0.8950 - final_regr: 0.2730axes don't match array
# 196/250 [======================>.......] - ETA: 1:40 - rpn_cls: 5.4584 - rpn_regr: 0.4266 - final_cls: 0.8947 - final_regr: 0.2732not enough values to unpack (expected 3, got 2)
# 197/250 [======================>.......] - ETA: 1:39 - rpn_cls: 5.4591 - rpn_regr: 0.4266 - final_cls: 0.8947 - final_regr: 0.2733axes don't match array
# 221/250 [=========================>....] - ETA: 55s - rpn_cls: 5.4694 - rpn_regr: 0.4272 - final_cls: 0.8940 - final_regr: 0.2750axes don't match array
# 250/250 [==============================] - 476s 2s/step - rpn_cls: 5.4768 - rpn_regr: 0.4280 - final_cls: 0.8930 - final_regr: 0.2766
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.3734939759036147
# Classifier accuracy for bounding boxes from RPN: 0.695
# Loss RPN classifier: 5.533919662934166
# Loss RPN regression: 0.4363209021575749
# Loss Detector classifier: 0.8825868073180317
# Loss Detector regression: 0.286085914671421
# Total loss: 7.138913287081194
# Elapsed time: 475.85077261924744
# Epoch 26/50
#   1/250 [..............................] - ETA: 3:15 - rpn_cls: 6.6355 - rpn_regr: 0.2317 - final_cls: 0.5082 - final_regr: 0.0000e+00axes don't match array
# axes don't match array
#  29/250 [==>...........................] - ETA: 7:28 - rpn_cls: 4.3051 - rpn_regr: 0.3338 - final_cls: 0.8242 - final_regr: 0.2362axes don't match array
# 118/250 [=============>................] - ETA: 4:10 - rpn_cls: 5.3780 - rpn_regr: 0.3636 - final_cls: 0.8412 - final_regr: 0.2745axes don't match array
# 123/250 [=============>................] - ETA: 4:03 - rpn_cls: 5.3900 - rpn_regr: 0.3663 - final_cls: 0.8427 - final_regr: 0.2752axes don't match array
# 188/250 [=====================>........] - ETA: 1:57 - rpn_cls: 5.4978 - rpn_regr: 0.4010 - final_cls: 0.8497 - final_regr: 0.2823not enough values to unpack (expected 3, got 2)
# 248/250 [============================>.] - ETA: 3s - rpn_cls: 5.5417 - rpn_regr: 0.4176 - final_cls: 0.8565 - final_regr: 0.2860axes don't match array
# 250/250 [==============================] - 478s 2s/step - rpn_cls: 5.5423 - rpn_regr: 0.4180 - final_cls: 0.8567 - final_regr: 0.2861
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.770940170940171
# Classifier accuracy for bounding boxes from RPN: 0.688
# Loss RPN classifier: 5.610012835677138
# Loss RPN regression: 0.4699062437713146
# Loss Detector classifier: 0.8834019114822149
# Loss Detector regression: 0.29699022449553014
# Total loss: 7.260311215426198
# Elapsed time: 478.2110381126404
# Epoch 27/50
#  13/250 [>.............................] - ETA: 6:19 - rpn_cls: 3.2079 - rpn_regr: 0.5139 - final_cls: 0.8535 - final_regr: 0.2397not enough values to unpack (expected 3, got 2)
#  37/250 [===>..........................] - ETA: 6:29 - rpn_cls: 4.1160 - rpn_regr: 0.4519 - final_cls: 0.9502 - final_regr: 0.3480axes don't match array
#  43/250 [====>.........................] - ETA: 6:25 - rpn_cls: 4.1967 - rpn_regr: 0.4466 - final_cls: 0.9581 - final_regr: 0.3531axes don't match array
#  92/250 [==========>...................] - ETA: 4:59 - rpn_cls: 4.6453 - rpn_regr: 0.4305 - final_cls: 0.9578 - final_regr: 0.3529axes don't match array
# 169/250 [===================>..........] - ETA: 2:22 - rpn_cls: 4.9356 - rpn_regr: 0.4332 - final_cls: 0.9335 - final_regr: 0.3383axes don't match array
# 217/250 [=========================>....] - ETA: 59s - rpn_cls: 5.0324 - rpn_regr: 0.4358 - final_cls: 0.9231 - final_regr: 0.3303 axes don't match array
# 250/250 [==============================] - 443s 2s/step - rpn_cls: 5.0990 - rpn_regr: 0.4361 - final_cls: 0.9189 - final_regr: 0.3264
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.8766355140186914
# Classifier accuracy for bounding boxes from RPN: 0.693
# Loss RPN classifier: 5.618228055790711
# Loss RPN regression: 0.44041161533817647
# Loss Detector classifier: 0.884930162742734
# Loss Detector regression: 0.29888600523769854
# Total loss: 7.2424558391093194
# Elapsed time: 442.8455286026001
# Epoch 28/50
#  34/250 [===>..........................] - ETA: 5:38 - rpn_cls: 5.4842 - rpn_regr: 0.3610 - final_cls: 0.6398 - final_regr: 0.1872not enough values to unpack (expected 3, got 2)
#  91/250 [=========>....................] - ETA: 4:11 - rpn_cls: 5.4825 - rpn_regr: 0.4140 - final_cls: 0.7579 - final_regr: 0.2505axes don't match array
# axes don't match array
# 135/250 [===============>..............] - ETA: 3:12 - rpn_cls: 5.5504 - rpn_regr: 0.4230 - final_cls: 0.7849 - final_regr: 0.2648not enough values to unpack (expected 3, got 2)
# 194/250 [======================>.......] - ETA: 1:40 - rpn_cls: 5.5903 - rpn_regr: 0.4322 - final_cls: 0.8057 - final_regr: 0.2756axes don't match array
# 250/250 [==============================] - 433s 2s/step - rpn_cls: 5.6206 - rpn_regr: 0.4403 - final_cls: 0.8185 - final_regr: 0.2809
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.9042145593869733
# Classifier accuracy for bounding boxes from RPN: 0.693
# Loss RPN classifier: 5.793147807255806
# Loss RPN regression: 0.46481443411111834
# Loss Detector classifier: 0.8686595432758332
# Loss Detector regression: 0.30192031210660936
# Total loss: 7.428542096749366
# Elapsed time: 433.13398003578186
# Epoch 29/50
#  55/250 [=====>........................] - ETA: 5:57 - rpn_cls: 6.1347 - rpn_regr: 0.3458 - final_cls: 1.1066 - final_regr: 0.4057axes don't match array
# 177/250 [====================>.........] - ETA: 2:08 - rpn_cls: 5.7584 - rpn_regr: 0.3754 - final_cls: 0.9938 - final_regr: 0.3685not enough values to unpack (expected 3, got 2)
# 191/250 [=====================>........] - ETA: 1:44 - rpn_cls: 5.7204 - rpn_regr: 0.3771 - final_cls: 0.9894 - final_regr: 0.3667axes don't match array
# 193/250 [======================>.......] - ETA: 1:41 - rpn_cls: 5.7145 - rpn_regr: 0.3774 - final_cls: 0.9888 - final_regr: 0.3664axes don't match array
# 214/250 [========================>.....] - ETA: 1:04 - rpn_cls: 5.6549 - rpn_regr: 0.3801 - final_cls: 0.9832 - final_regr: 0.3636axes don't match array
# 250/250 [==============================] - 456s 2s/step - rpn_cls: 5.5719 - rpn_regr: 0.3841 - final_cls: 0.9756 - final_regr: 0.3604
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.0394973070017954
# Classifier accuracy for bounding boxes from RPN: 0.651
# Loss RPN classifier: 5.1222670022826735
# Loss RPN regression: 0.4031826137937605
# Loss Detector classifier: 0.9289589978158473
# Loss Detector regression: 0.34741711016744375
# Total loss: 6.801825724059726
# Elapsed time: 455.8018169403076
# Epoch 30/50
#   5/250 [..............................] - ETA: 5:41 - rpn_cls: 2.9754 - rpn_regr: 0.1935 - final_cls: 1.6069 - final_regr: 0.3401axes don't match array
#   9/250 [>.............................] - ETA: 5:12 - rpn_cls: 3.9030 - rpn_regr: 0.2479 - final_cls: 1.3650 - final_regr: 0.2979not enough values to unpack (expected 3, got 2)
# axes don't match array
#  11/250 [>.............................] - ETA: 6:45 - rpn_cls: 4.3293 - rpn_regr: 0.2535 - final_cls: 1.2957 - final_regr: 0.2929not enough values to unpack (expected 3, got 2)
#  14/250 [>.............................] - ETA: 7:05 - rpn_cls: 4.6906 - rpn_regr: 0.2592 - final_cls: 1.2259 - final_regr: 0.2868axes don't match array
# 115/250 [============>.................] - ETA: 4:11 - rpn_cls: 5.1772 - rpn_regr: 0.3718 - final_cls: 0.9813 - final_regr: 0.3028axes don't match array
# 119/250 [=============>................] - ETA: 4:04 - rpn_cls: 5.1707 - rpn_regr: 0.3738 - final_cls: 0.9818 - final_regr: 0.3037not enough values to unpack (expected 3, got 2)
# 135/250 [===============>..............] - ETA: 3:30 - rpn_cls: 5.1466 - rpn_regr: 0.3810 - final_cls: 0.9827 - final_regr: 0.3067axes don't match array
# 137/250 [===============>..............] - ETA: 3:28 - rpn_cls: 5.1445 - rpn_regr: 0.3818 - final_cls: 0.9827 - final_regr: 0.3071not enough values to unpack (expected 3, got 2)
# 189/250 [=====================>........] - ETA: 1:50 - rpn_cls: 5.1371 - rpn_regr: 0.3948 - final_cls: 0.9760 - final_regr: 0.3127not enough values to unpack (expected 3, got 2)
# 209/250 [========================>.....] - ETA: 1:13 - rpn_cls: 5.1443 - rpn_regr: 0.3975 - final_cls: 0.9736 - final_regr: 0.3144axes don't match array
# 214/250 [========================>.....] - ETA: 1:04 - rpn_cls: 5.1477 - rpn_regr: 0.3981 - final_cls: 0.9730 - final_regr: 0.3146axes don't match array
# 234/250 [===========================>..] - ETA: 29s - rpn_cls: 5.1624 - rpn_regr: 0.4003 - final_cls: 0.9707 - final_regr: 0.3155not enough values to unpack (expected 3, got 2)
# 250/250 [==============================] - 458s 2s/step - rpn_cls: 5.1701 - rpn_regr: 0.4018 - final_cls: 0.9692 - final_regr: 0.3162
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.223853211009174
# ...
# 250/250 [==============================] - 434s 2s/step - rpn_cls: 5.4654 - rpn_regr: 0.4832 - final_cls: 0.9068 - final_regr: 0.2842
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.549056603773585
# Classifier accuracy for bounding boxes from RPN: 0.686
# Loss RPN classifier: 5.70645120986455
# Loss RPN regression: 0.45135197845846414
# Loss Detector classifier: 0.9138998785018921
# Loss Detector regression: 0.2909614903740585
# Total loss: 7.362664557198965
# Elapsed time: 433.7605230808258
# Epoch 42/50
#  65/250 [======>.......................] - ETA: 5:18 - rpn_cls: 5.1078 - rpn_regr: 0.5101 - final_cls: 0.8493 - final_regr: 0.3118not enough values to unpack (expected 3, got 2)
#  78/250 [========>.....................] - ETA: 5:11 - rpn_cls: 5.0842 - rpn_regr: 0.5015 - final_cls: 0.8567 - final_regr: 0.3108axes don't match array
#  80/250 [========>.....................] - ETA: 5:05 - rpn_cls: 5.0759 - rpn_regr: 0.5005 - final_cls: 0.8582 - final_regr: 0.3108not enough values to unpack (expected 3, got 2)
# 102/250 [===========>..................] - ETA: 4:24 - rpn_cls: 5.0030 - rpn_regr: 0.4867 - final_cls: 0.8680 - final_regr: 0.3094axes don't match array
# 145/250 [================>.............] - ETA: 3:11 - rpn_cls: 4.9523 - rpn_regr: 0.4716 - final_cls: 0.8781 - final_regr: 0.3098not enough values to unpack (expected 3, got 2)
# 149/250 [================>.............] - ETA: 3:02 - rpn_cls: 4.9523 - rpn_regr: 0.4703 - final_cls: 0.8786 - final_regr: 0.3099axes don't match array
# axes don't match array
# 151/250 [=================>............] - ETA: 3:00 - rpn_cls: 4.9528 - rpn_regr: 0.4696 - final_cls: 0.8788 - final_regr: 0.3099axes don't match array
# 154/250 [=================>............] - ETA: 2:55 - rpn_cls: 4.9530 - rpn_regr: 0.4685 - final_cls: 0.8792 - final_regr: 0.3101axes don't match array
# 250/250 [==============================] - 460s 2s/step - rpn_cls: 4.9523 - rpn_regr: 0.4501 - final_cls: 0.8879 - final_regr: 0.3133
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.3518850987432676
# Classifier accuracy for bounding boxes from RPN: 0.656
# Loss RPN classifier: 4.938448855303264
# Loss RPN regression: 0.43030632931366564
# Loss Detector classifier: 0.925771919310093
# Loss Detector regression: 0.3353045075237751
# Total loss: 6.629831611450798
# Elapsed time: 459.6073987483978
# Epoch 43/50
#   5/250 [..............................] - ETA: 9:06 - rpn_cls: 2.2028 - rpn_regr: 0.1755 - final_cls: 1.3547 - final_regr: 0.4047axes don't match array
#   9/250 [>.............................] - ETA: 8:28 - rpn_cls: 3.0689 - rpn_regr: 0.2091 - final_cls: 1.2650 - final_regr: 0.4104axes don't match array
#  24/250 [=>............................] - ETA: 6:56 - rpn_cls: 4.0347 - rpn_regr: 0.3105 - final_cls: 1.0947 - final_regr: 0.3993axes don't match array
#  25/250 [==>...........................] - ETA: 7:07 - rpn_cls: 4.0615 - rpn_regr: 0.3138 - final_cls: 1.0887 - final_regr: 0.3985not enough values to unpack (expected 3, got 2)
#  76/250 [========>.....................] - ETA: 5:18 - rpn_cls: 5.0992 - rpn_regr: 0.3623 - final_cls: 0.9555 - final_regr: 0.3548axes don't match array
#  96/250 [==========>...................] - ETA: 4:32 - rpn_cls: 5.1471 - rpn_regr: 0.3680 - final_cls: 0.9452 - final_regr: 0.3498axes don't match array
# 101/250 [===========>..................] - ETA: 4:25 - rpn_cls: 5.1570 - rpn_regr: 0.3692 - final_cls: 0.9432 - final_regr: 0.3485not enough values to unpack (expected 3, got 2)
# 122/250 [=============>................] - ETA: 3:53 - rpn_cls: 5.1923 - rpn_regr: 0.3740 - final_cls: 0.9377 - final_regr: 0.3424axes don't match array
# 150/250 [=================>............] - ETA: 3:03 - rpn_cls: 5.2134 - rpn_regr: 0.3790 - final_cls: 0.9326 - final_regr: 0.3376axes don't match array
# 157/250 [=================>............] - ETA: 2:52 - rpn_cls: 5.2143 - rpn_regr: 0.3802 - final_cls: 0.9316 - final_regr: 0.3366not enough values to unpack (expected 3, got 2)
# 191/250 [=====================>........] - ETA: 1:50 - rpn_cls: 5.2214 - rpn_regr: 0.3844 - final_cls: 0.9296 - final_regr: 0.3336axes don't match array
# 250/250 [==============================] - 464s 2s/step - rpn_cls: 5.2346 - rpn_regr: 0.3928 - final_cls: 0.9254 - final_regr: 0.3300
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.319715808170515
# Classifier accuracy for bounding boxes from RPN: 0.666
# Loss RPN classifier: 5.247800640974703
# Loss RPN regression: 0.4283148443251848
# Loss Detector classifier: 0.9151843921542168
# Loss Detector regression: 0.32123155108094215
# Total loss: 6.912531428535047
# Elapsed time: 463.52498149871826
# Epoch 44/50
# 110/250 [============>.................] - ETA: 4:06 - rpn_cls: 5.3459 - rpn_regr: 0.4243 - final_cls: 0.8108 - final_regr: 0.2580axes don't match array
# 139/250 [===============>..............] - ETA: 3:25 - rpn_cls: 5.3224 - rpn_regr: 0.4258 - final_cls: 0.8173 - final_regr: 0.2624axes don't match array
# 142/250 [================>.............] - ETA: 3:19 - rpn_cls: 5.3192 - rpn_regr: 0.4262 - final_cls: 0.8174 - final_regr: 0.2626axes don't match array
# 143/250 [================>.............] - ETA: 3:19 - rpn_cls: 5.3179 - rpn_regr: 0.4263 - final_cls: 0.8175 - final_regr: 0.2627axes don't match array
# 168/250 [===================>..........] - ETA: 2:34 - rpn_cls: 5.2868 - rpn_regr: 0.4293 - final_cls: 0.8193 - final_regr: 0.2638axes don't match array
# 200/250 [=======================>......] - ETA: 1:33 - rpn_cls: 5.2562 - rpn_regr: 0.4327 - final_cls: 0.8200 - final_regr: 0.2654axes don't match array
# axes don't match array
# 232/250 [==========================>...] - ETA: 33s - rpn_cls: 5.2314 - rpn_regr: 0.4343 - final_cls: 0.8212 - final_regr: 0.2667axes don't match array
# 250/250 [==============================] - 467s 2s/step - rpn_cls: 5.2301 - rpn_regr: 0.4345 - final_cls: 0.8223 - final_regr: 0.2674
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.749559082892416
# Classifier accuracy for bounding boxes from RPN: 0.711
# Loss RPN classifier: 5.22772802981402
# Loss RPN regression: 0.43976626730337737
# Loss Detector classifier: 0.8376741380393505
# Loss Detector regression: 0.2765201233252883
# Total loss: 6.781688558482036
# Elapsed time: 467.11316657066345
# Epoch 45/50
#  72/250 [=======>......................] - ETA: 5:21 - rpn_cls: 5.7897 - rpn_regr: 0.4500 - final_cls: 0.7464 - final_regr: 0.2831not enough values to unpack (expected 3, got 2)
#  77/250 [========>.....................] - ETA: 5:19 - rpn_cls: 5.7482 - rpn_regr: 0.4519 - final_cls: 0.7508 - final_regr: 0.2834axes don't match array
# 141/250 [===============>..............] - ETA: 3:22 - rpn_cls: 5.5883 - rpn_regr: 0.4770 - final_cls: 0.7839 - final_regr: 0.2904not enough values to unpack (expected 3, got 2)
# 201/250 [=======================>......] - ETA: 1:32 - rpn_cls: 5.4963 - rpn_regr: 0.4852 - final_cls: 0.8071 - final_regr: 0.2958not enough values to unpack (expected 3, got 2)
# 215/250 [========================>.....] - ETA: 1:06 - rpn_cls: 5.4761 - rpn_regr: 0.4854 - final_cls: 0.8120 - final_regr: 0.2965not enough values to unpack (expected 3, got 2)
# 240/250 [===========================>..] - ETA: 18s - rpn_cls: 5.4422 - rpn_regr: 0.4847 - final_cls: 0.8205 - final_regr: 0.2990not enough values to unpack (expected 3, got 2)
# 246/250 [============================>.] - ETA: 7s - rpn_cls: 5.4343 - rpn_regr: 0.4845 - final_cls: 0.8223 - final_regr: 0.2994not enough values to unpack (expected 3, got 2)
# 250/250 [==============================] - 473s 2s/step - rpn_cls: 5.4295 - rpn_regr: 0.4843 - final_cls: 0.8235 - final_regr: 0.2997
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 2.6996527777777777
# Classifier accuracy for bounding boxes from RPN: 0.67
# Loss RPN classifier: 5.122180897003367
# Loss RPN regression: 0.4724956325814128
# Loss Detector classifier: 0.896631543174386
# Loss Detector regression: 0.317516683280468
# Total loss: 6.808824756039633
# Elapsed time: 472.6880269050598
# Epoch 46/50
#  45/250 [====>.........................] - ETA: 6:36 - rpn_cls: 6.8651 - rpn_regr: 0.4153 - final_cls: 0.8162 - final_regr: 0.2866axes don't match array
# 122/250 [=============>................] - ETA: 3:40 - rpn_cls: 5.8519 - rpn_regr: 0.4320 - final_cls: 0.8481 - final_regr: 0.2826axes don't match array
# 171/250 [===================>..........] - ETA: 2:18 - rpn_cls: 5.7185 - rpn_regr: 0.4379 - final_cls: 0.8481 - final_regr: 0.2754axes don't match array
# 240/250 [===========================>..] - ETA: 16s - rpn_cls: 5.6305 - rpn_regr: 0.4402 - final_cls: 0.8469 - final_regr: 0.2750axes don't match array
# 250/250 [==============================] - 421s 2s/step - rpn_cls: 5.6264 - rpn_regr: 0.4402 - final_cls: 0.8466 - final_regr: 0.2752
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.009746588693957
# Classifier accuracy for bounding boxes from RPN: 0.707
# Loss RPN classifier: 5.486814878517454
# Loss RPN regression: 0.43711267689988015
# Loss Detector classifier: 0.8395992276966572
# Loss Detector regression: 0.2791121420543641
# Total loss: 7.042638925168355
# Elapsed time: 421.2679395675659
# Epoch 47/50
#  47/250 [====>.........................] - ETA: 5:21 - rpn_cls: 6.1253 - rpn_regr: 0.5803 - final_cls: 0.8928 - final_regr: 0.3379axes don't match array
# not enough values to unpack (expected 3, got 2)
#  89/250 [=========>....................] - ETA: 4:43 - rpn_cls: 5.6047 - rpn_regr: 0.5271 - final_cls: 0.9163 - final_regr: 0.3376axes don't match array
# 151/250 [=================>............] - ETA: 3:01 - rpn_cls: 5.3946 - rpn_regr: 0.5063 - final_cls: 0.9218 - final_regr: 0.3291axes don't match array
# 250/250 [==============================] - 435s 2s/step - rpn_cls: 5.4275 - rpn_regr: 0.4991 - final_cls: 0.9173 - final_regr: 0.3205
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.666034155597723
# Classifier accuracy for bounding boxes from RPN: 0.671
# Loss RPN classifier: 5.681828083672459
# Loss RPN regression: 0.4716469960063696
# Loss Detector classifier: 0.9251519714295864
# Loss Detector regression: 0.3149980114251375
# Total loss: 7.393625062533552
# Elapsed time: 434.8973741531372
# Epoch 48/50
#  12/250 [>.............................] - ETA: 8:47 - rpn_cls: 5.1443 - rpn_regr: 0.4859 - final_cls: 0.9440 - final_regr: 0.3689not enough values to unpack (expected 3, got 2)
# 135/250 [===============>..............] - ETA: 3:19 - rpn_cls: 5.3161 - rpn_regr: 0.4055 - final_cls: 0.9319 - final_regr: 0.3188not enough values to unpack (expected 3, got 2)
# 150/250 [=================>............] - ETA: 2:55 - rpn_cls: 5.2893 - rpn_regr: 0.4058 - final_cls: 0.9322 - final_regr: 0.3177axes don't match array
# 152/250 [=================>............] - ETA: 2:51 - rpn_cls: 5.2850 - rpn_regr: 0.4060 - final_cls: 0.9322 - final_regr: 0.3175axes don't match array
# 174/250 [===================>..........] - ETA: 2:13 - rpn_cls: 5.2415 - rpn_regr: 0.4077 - final_cls: 0.9318 - final_regr: 0.3161not enough values to unpack (expected 3, got 2)
# 216/250 [========================>.....] - ETA: 1:00 - rpn_cls: 5.1804 - rpn_regr: 0.4102 - final_cls: 0.9315 - final_regr: 0.3157not enough values to unpack (expected 3, got 2)
# 220/250 [=========================>....] - ETA: 53s - rpn_cls: 5.1764 - rpn_regr: 0.4102 - final_cls: 0.9315 - final_regr: 0.3156not enough values to unpack (expected 3, got 2)
# not enough values to unpack (expected 3, got 2)
# 222/250 [=========================>....] - ETA: 50s - rpn_cls: 5.1749 - rpn_regr: 0.4102 - final_cls: 0.9315 - final_regr: 0.3156axes don't match array
# 225/250 [==========================>...] - ETA: 44s - rpn_cls: 5.1728 - rpn_regr: 0.4102 - final_cls: 0.9314 - final_regr: 0.3155axes don't match array
# 250/250 [==============================] - 451s 2s/step - rpn_cls: 5.1572 - rpn_regr: 0.4099 - final_cls: 0.9310 - final_regr: 0.3150
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.2813067150635207
# Classifier accuracy for bounding boxes from RPN: 0.655
# Loss RPN classifier: 4.956335095848439
# Loss RPN regression: 0.4021674917936325
# Loss Detector classifier: 0.936150822609663
# Loss Detector regression: 0.3104789186790585
# Total loss: 6.605132328930793
# Elapsed time: 450.83871698379517
# Epoch 49/50
#  76/250 [========>.....................] - ETA: 5:22 - rpn_cls: 4.2795 - rpn_regr: 0.4480 - final_cls: 0.9213 - final_regr: 0.2604axes don't match array
#  81/250 [========>.....................] - ETA: 5:10 - rpn_cls: 4.3080 - rpn_regr: 0.4479 - final_cls: 0.9265 - final_regr: 0.2649not enough values to unpack (expected 3, got 2)
#  97/250 [==========>...................] - ETA: 4:36 - rpn_cls: 4.3707 - rpn_regr: 0.4489 - final_cls: 0.9365 - final_regr: 0.2749axes don't match array
#  99/250 [==========>...................] - ETA: 4:34 - rpn_cls: 4.3775 - rpn_regr: 0.4490 - final_cls: 0.9373 - final_regr: 0.2758not enough values to unpack (expected 3, got 2)
# 150/250 [=================>............] - ETA: 3:00 - rpn_cls: 4.5246 - rpn_regr: 0.4472 - final_cls: 0.9359 - final_regr: 0.2875axes don't match array
# 170/250 [===================>..........] - ETA: 2:22 - rpn_cls: 4.5727 - rpn_regr: 0.4456 - final_cls: 0.9352 - final_regr: 0.2915axes don't match array
# 175/250 [====================>.........] - ETA: 2:13 - rpn_cls: 4.5870 - rpn_regr: 0.4453 - final_cls: 0.9350 - final_regr: 0.2924axes don't match array
# 195/250 [======================>.......] - ETA: 1:39 - rpn_cls: 4.6308 - rpn_regr: 0.4441 - final_cls: 0.9352 - final_regr: 0.2951not enough values to unpack (expected 3, got 2)
# 220/250 [=========================>....] - ETA: 55s - rpn_cls: 4.6623 - rpn_regr: 0.4427 - final_cls: 0.9348 - final_regr: 0.2979not enough values to unpack (expected 3, got 2)
# 226/250 [==========================>...] - ETA: 44s - rpn_cls: 4.6684 - rpn_regr: 0.4422 - final_cls: 0.9346 - final_regr: 0.2985axes don't match array
# 250/250 [==============================] - 475s 2s/step - rpn_cls: 4.6921 - rpn_regr: 0.4402 - final_cls: 0.9339 - final_regr: 0.3006
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.3472949389179756
# Classifier accuracy for bounding boxes from RPN: 0.654
# Loss RPN classifier: 4.948357904916118
# Loss RPN regression: 0.4177107707411051
# Loss Detector classifier: 0.9297055108994245
# Loss Detector regression: 0.3214618282020092
# Total loss: 6.617236014758657
# Elapsed time: 474.8939538002014
# Epoch 50/50
#   9/250 [>.............................] - ETA: 6:26 - rpn_cls: 4.5468 - rpn_regr: 0.3750 - final_cls: 0.9701 - final_regr: 0.3505not enough values to unpack (expected 3, got 2)
# 180/250 [====================>.........] - ETA: 2:02 - rpn_cls: 5.1093 - rpn_regr: 0.4482 - final_cls: 0.9210 - final_regr: 0.2821not enough values to unpack (expected 3, got 2)
# 210/250 [========================>.....] - ETA: 1:12 - rpn_cls: 5.1251 - rpn_regr: 0.4496 - final_cls: 0.9178 - final_regr: 0.2826axes don't match array
# 213/250 [========================>.....] - ETA: 1:06 - rpn_cls: 5.1261 - rpn_regr: 0.4498 - final_cls: 0.9174 - final_regr: 0.2826axes don't match array
# 214/250 [========================>.....] - ETA: 1:05 - rpn_cls: 5.1265 - rpn_regr: 0.4498 - final_cls: 0.9173 - final_regr: 0.2826not enough values to unpack (expected 3, got 2)
# 239/250 [===========================>..] - ETA: 20s - rpn_cls: 5.1303 - rpn_regr: 0.4509 - final_cls: 0.9153 - final_regr: 0.2833not enough values to unpack (expected 3, got 2)
# 250/250 [==============================] - 462s 2s/step - rpn_cls: 5.1318 - rpn_regr: 0.4513 - final_cls: 0.9144 - final_regr: 0.2836
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.2805755395683454
# Classifier accuracy for bounding boxes from RPN: 0.688
# Loss RPN classifier: 5.178588664020222
# Loss RPN regression: 0.46005315238796174
# Loss Detector classifier: 0.8958766680061817
# Loss Detector regression: 0.29044316393136976
# Total loss: 6.824961648345735
# Elapsed time: 461.8060348033905
# Training complete, exiting.

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(np.arange(0, r_epochs), record_df['mean_overlapping_bboxes'], 'r')
plt.title('mean_overlapping_bboxes')
plt.subplot(1,2,2)
plt.plot(np.arange(0, r_epochs), record_df['class_acc'], 'r')
plt.title('class_acc')

plt.show()

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(np.arange(0, r_epochs), record_df['loss_rpn_cls'], 'r')
plt.title('loss_rpn_cls')
plt.subplot(1,2,2)
plt.plot(np.arange(0, r_epochs), record_df['loss_rpn_regr'], 'r')
plt.title('loss_rpn_regr')
plt.show()


plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(np.arange(0, r_epochs), record_df['loss_class_cls'], 'r')
plt.title('loss_class_cls')
plt.subplot(1,2,2)
plt.plot(np.arange(0, r_epochs), record_df['loss_class_regr'], 'r')
plt.title('loss_class_regr')
plt.show()

plt.plot(np.arange(0, r_epochs), record_df['curr_loss'], 'r')
plt.title('total_loss')
plt.show()

# plt.figure(figsize=(15,5))
# plt.subplot(1,2,1)
# plt.plot(np.arange(0, r_epochs), record_df['curr_loss'], 'r')
# plt.title('total_loss')
# plt.subplot(1,2,2)
# plt.plot(np.arange(0, r_epochs), record_df['elapsed_time'], 'r')
# plt.title('elapsed_time')
# plt.show()

# plt.title('loss')
# plt.plot(np.arange(0, r_epochs), record_df['loss_rpn_cls'], 'b')
# plt.plot(np.arange(0, r_epochs), record_df['loss_rpn_regr'], 'g')
# plt.plot(np.arange(0, r_epochs), record_df['loss_class_cls'], 'r')
# plt.plot(np.arange(0, r_epochs), record_df['loss_class_regr'], 'c')
# # plt.plot(np.arange(0, r_epochs), record_df['curr_loss'], 'm')
# plt.show()
